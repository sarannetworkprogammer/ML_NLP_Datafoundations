# %% [markdown]
# <a href="https://colab.research.google.com/github/sarannetworkprogammer/Data_foundations/blob/main/Saran_PS2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Problem Set 2
#
# Name:
# abc123:
#
#
# Collaborators:
# - Colaborator 1 :
# - Colaborator 2 :
#
# ### Introduction
# You are a data scientist working for the government. You want to understand the public opinion regarding hurricane Maria which is responsible for killing at least 499 people in Puerto Rico. Total losses are estimated at $94.4 billion dollars which accrued to government agencies, businesses, and more importantly, familes [1]. With this background, whether you are a politician, bussiness person, or one effected by the hurricane, understanding the sentiment of the general populace is important. For this assigment, you will use a subset of the tweets retrieved from Twitter that mentioned #PuertoRico over the period of October 4 to November 7, 2017 [2] to measure the sentiment (i.e., the "good" or "bad" opinions people have about the hurricane and its impact) of this event.
#
# For this task, we will write code for a lexicon-based analysis (i.e., lexicon-based classification). Lexicon-based classification is a way to categorize text based using manually generated lists of topical words. Essentially, we just need to check if the topical words appear in a piece of text (e.g., a tweet). In this exercise we will make use of manually curated sentiment words. However, the basic experimental process is the same for other tasks (e.g., identifying offensive language).
#
# If you are interested, though it is not needed, you can learn more about lexicon-based classification in Chapter 21 (21.2 and 21.6) of the free online book at the following link: [Speech and Language Processing](https://web.stanford.edu/~jurafsky/slp3/21.pdf)
#
# ### References
# [1]  Spalding, Rebecca (November 13, 2017). "Puerto Rico Seeks $94 Billion in Federal Aid for Hurricane Recovery". Bloomberg News. Retrieved December 15, 2017.
#
# [2]  site: https://archive.org/details/puertorico-tweets
#
# ## Submission Instructions
#
# After completing the exercises below, generate a pdf of the code **with** outputs. After that create a zip file containing both the completed exercise and the generated PDF/HTML. You are **required** to check the PDF/HTML to make sure all the code **and** outputs are clearly visible and easy to read. If your code goes off the page, you should reduce the line size. I generally recommend not going over 80 characters.
#
# For this task, unzip and move the file "puerto-rico.jsonl" in to the same directory as this notebook, then complete the following exercises. However, when you turn the assigment in, do **NOT** include puerto-rico.jsonl in your zip file when you submit the homework, you will kill Blackboard.
#
# Finally, name the zip file using a combination of your the assigment and your name, e.g., ps2_rios.zip

# %% [markdown]
# ## Exercise 1 (1 points)
#
# The files "positive_words.txt" and "negative_words.txt" contain mannually curated positive (e.g., good, great, awesome) and negative words (e.g., bad, hate, terrible). The files contain one word on each line. Write a function that takes the open file (i.e., the file handle) and adds the words (i.e., on each line) to a set then returns the set.
#
# **Note:** You should use ".strip()" to remove the newline character from the end of each word.

# %%
# Write code here

def file_to_set(file):

    words =set()

    for row in file:
      words.add(row.strip())

    return words 

positive_file = open("/content/drive/MyDrive/Colab Notebooks/bing_liu/positive-words.txt", encoding='utf8')
positive_words = file_to_set(positive_file)
positive_file.close()
negative_file = open('/content/drive/MyDrive/Colab Notebooks/bing_liu/negative-words.txt', encoding='iso-8859-1')
negative_words = file_to_set(negative_file)
negative_file.close()

# %% [markdown]
# The lines below give example inputs and correct outputs using asserts, and can be run to test the code. Passing these tests is necessary, but **NOT** sufficient to guarantee your implementation is correct. You may add additional test cases, but do not remove any tests.

# %%
assert(type(positive_words) == type(set()))
assert(type(negative_words) == type(set()))
assert(len(positive_words) == 2006)
assert(len(negative_words) == 4783)
assert(('good' in positive_words)  == True)
assert(('bad' in negative_words)  == True)
assert(('bad' not in positive_words) == True)
print("Asserts finished successfully!")
# Out:
# Asserts finished successfully!

# %% [markdown]
# ## Exercise 2 (1 points)
#
# For this exercise, you need to write a function that counts the number of words in a sentence that also appear in a set. For example, given the set set(['good', 'great']) and the sentence "this is good good good", the function should return 3. The lower parameter should lowercase the input tweet text if it is set to True. Otherwise, it should keep the tweet text as-is.
#
# **Hint:** You can check if something is in a set using the following notation:
#
# ```python
# mySet = set(["a", "b", "c"])
# otherList = ["c", "d"]
# for letter in otherList:
#     if letter in mySet:
#         print(letter)
# ```
#
# The above code will print "c".

# %%
def count_sentiment_words(sentiment_set, tweet_text, lower):
  
    if lower is True:
      text = tweet_text.lower()
    else:
      text = tweet_text

    count = 0
    for word in text.split():
      if word in sentiment_set:
        count = count + 1
    return count

# %% [markdown]
# The lines below give example inputs and correct outputs using asserts, and can be run to test the code. Passing these tests is necessary, but **NOT** sufficient to guarantee your implementation is correct. You may add additional test cases, but do not remove any tests.

# %%
assert(count_sentiment_words(positive_words, "this is a good good good class", True) == 3)
assert(count_sentiment_words(positive_words, "this is a good\tgood\tgood class", True) == 3)
assert(count_sentiment_words(positive_words, "this is a GOOD GOOD GOOD class", False) == 0)
assert(count_sentiment_words(positive_words, "this is a GOOD GOOD GOOD class", True) == 3)
assert(count_sentiment_words(positive_words, "this is a GOOD GOOD good class", False) == 1)
assert(count_sentiment_words(positive_words, "Python is the best programming language for data science", True) == 1)
assert(count_sentiment_words(negative_words, "R is bad compared to Python ;)", True) == 1)

# %% [markdown]
# ## Exercise 3 (1 point)
#
# For this exercise, you will write a function that takes two numbers as input and returns a string. Intuitively, this is a basic classification function for lexicon-based sentiment classification.
#
# The function should take as input parameters the the number of positive (num_pos_words) and negative (num_neg_words) words in each tweet to predict sentiment. If the number of positive words is greater than to the number of negative tweets (num_pos_words > num_neg_words), then predict **"positive"**. If the number of negative words is greater than the number of positive words (num_neg_words > num_pos_words), then predict **"negative"**. If both num_pos_words and num_neg_words are equal (num_neg_words = num_pos_words), predict **"neutral"**. This is known as lexicon-based classification.
#
# Intuitively, the idea is simple, a tweet with more positive words is generally express "positive" sentiment. Likewise, a tweet with more negative words is expressing "negative" sentiment.

# %%
def predict(num_pos_words, num_neg_words):
    """
    This function should return the string "positive", "negative", or "neutral" given
    the input parameters, i.e., if num_pos_words is greater than num_neg_words, return "positive"
    
        Parameters:
            - num_pos_words int: This is a count representing the number of positive words in a tweet.
            - num_neg_words int: This is a count representing the number of negative words in a tweet.
            
        Return:
            - Return a string "positive", "negative", or "neutral"

    """
    # Your code here

    if num_pos_words > num_neg_words:
      return "positive"
    
    elif num_pos_words < num_neg_words:
      return "negative"

    else:
      return "neutral"


# You should return a string

# %% [markdown]
# The lines below give example inputs and correct outputs using asserts, and can be run to test the code. Passing these tests is necessary, but **NOT** sufficient to guarantee your implementation is correct. You may add additional test cases, but do not remove any tests.

# %%
assert(predict(2, 5) == 'negative')
assert(predict(5, 2) == 'positive')
assert(predict(3, 3) == 'neutral')
print("Assert finished successfully!")
# Out:
# Assert finished successfully!

# %% [markdown]
# ## Exercise 4 (1 point)
#
# This exercise is similar to Exercise 3. However, instead of making a prediction, we should write a function that returns a sentiment score. Specifically, assume num_pos_words is 3 and num_neg_words is 4, the function should return -1. The idea is that the more *positive* the number, the more positive the sentiment. Likewise, the more *negative* the number, the more negative the sentiment.

# %%
def predict_score(num_pos_words, num_neg_words):
    """
    This function should generate a sentiment score num_pos_words - num_neg_words.
    
        Parameters:
            - num_pos_words int: This is a count representing the number of positive words in a tweet.
            - num_neg_words int: This is a count representing the number of negative words in a tweet.
            
        Return:
            - Return an integer representing the difference between positive words and negative words.
    """
    # Your code here

    score = num_pos_words - num_neg_words
    return score # You should return a number

# %% [markdown]
# The lines below give example inputs and correct outputs using asserts, and can be run to test the code. Passing these tests is necessary, but **NOT** sufficient to guarantee your implementation is correct. You may add additional test cases, but do not remove any tests.

# %%
assert(predict_score(3, 1) == 2)
assert(predict_score(2, 2) == 0)
assert(predict_score(2, 5) == -3)
print("Asserts finished successfully!")
# Out:
# Asserts finished successfully!

# %% [markdown]
# ## Exercise 5 (1 point)
#
# Write a function that takes a json string as input and returns a Python object. Hint: This can be one line. You can use the json library.

# %%
import json

def json_string_to_dictionary(json_string):
    """
    This function should take a json string and convert it into a Python object (hint: loads)
    
        Parameters:
            - json_string str: A json string, e.g., '{"a": 1}'
            
        Returns:
            - Return a python object, e.g., {"a": 1} <--- look no quotes, so this is a dictionary
    """
    # Your code here
    return json.loads(json_string)

# %% [markdown]
# The lines below give example inputs and correct outputs using asserts, and can be run to test the code. Passing these tests is necessary, but **NOT** sufficient to guarantee your implementation is correct. You may add additional test cases, but do not remove any tests.

# %%
data = json_string_to_dictionary('{"a": 1}')
assert(data == {'a': 1})
data = json_string_to_dictionary('[1,2,3]')
assert(data == [1,2,3])
print("Assert finished successfully!")
# Out:
# Assert finished successfully!

# %%
count = 0

dict1 ={}

def mosttweets(username):
  if not username in dict1:
    dict1[username] = 1
  else:   
    dict1[username] = dict1[username] + 1

twitter_dataset = open("/content/drive/MyDrive/Colab Notebooks/puerto-rico.jsonl", 'r')
for row in twitter_dataset:
    tweet_dict = json_string_to_dictionary(row)
    tweet_text = tweet_dict["full_text"]
    screen_name = tweet_dict["user"]["screen_name"]
    username = tweet_dict["user"]["name"].strip()
    mosttweets(username)
    
    #print(tweet_text)
    #print(screen_name)
    #print(f"username={username}")
    count = count + 1
    #if count == 100:
      #break
twitter_dataset.close()

#print(dict1)

#for key,value in dict1.items():
  #print(f"{key} = {value}")

max_value = max(dict1, key=dict1.get)
print(max_value)
# Out:
# Noti Puerto Rico🇵🇷

# %% [markdown]
# ## Exercise 6 (3 points)
#
# For this task, we combine the functions written for the previous exercises to classify all of the tweets in a real Twitter dataset. You should write code that does the following:
# 1. Keeps track of the number of tweets
# 2. Keeps track of the number of positive and negative tweets
# 3. Keeps track of the user that tweets the most
# 4. Keeps track of the total number of unique users
# 5. Keeps track of the average number of tweets per user (how many tweets does each user make, on average)
# 6. Keeps track of the most positive and negative tweets.
#
# Note: This task depends on Exercises 1 through 5. You will need to complete them first. Also, do **not** store all of the tweets in a list.  This will use too much memory because of the size of the dataset. It is okay to store all of the user's screen names.
#
# Finally, the dataset is big! So, I recommend working on a subset of the dataset to make sure your code works, i.e., you could "break" after the first 100 lines.

# %%
total_number_of_tweets = 0
total_number_of_positive_tweets = 0
total_number_of_negative_tweets = 0
total_number_of_neutral_tweets = 0

most_positive_tweet = ""
most_negative_tweet = ""
user_with_most_tweets = 0
average_number_tweets_per_user = 0
total_number_of_users =0

max_score = 0
min_score = 0

row_count = 0


dict1 ={}

def mosttweets(username):
  if not username in dict1:
    dict1[username] = 1
  else:   
    dict1[username] = dict1[username] + 1





# NOTE: You may need to define extra variables to help generate the required output.

twitter_dataset = open("/content/drive/MyDrive/Colab Notebooks/puerto-rico.jsonl", 'r')

# NOTE: Process the data line-by-line. Do NOT load the entire dataset into memory.
count = 0
for row in twitter_dataset:
    tweet_dict = json_string_to_dictionary(row)

    #for key,value in tweet_dict.items():
      #print(key , value )

    #if row_count == 1:
      #break
    
    row_count = row_count + 1


    ###############################
    
    tweet_text = tweet_dict["full_text"]
    total_number_of_tweets += 1                          # MODIFY THIS LINE TO GET THE "full_text" from the tweet_dict
    screen_name = tweet_dict["user"]["screen_name"]           # MODIFY THIS LINE TO GET THE "screen_name" from the tweet_dict
    
    ###############################
    
    num_pos_words = count_sentiment_words(positive_words, tweet_text, True)
    num_neg_words = count_sentiment_words(negative_words, tweet_text, True)
    
    sentiment_prediction = predict(num_pos_words, num_neg_words)
    sentiment_score = predict_score(num_pos_words, num_neg_words)


    if sentiment_score > 0:
    
      total_number_of_positive_tweets += 1

    if sentiment_score < 0:

      total_number_of_negative_tweets += 1
    
    if sentiment_score == 0:
      
      total_number_of_neutral_tweets += 1

    
    if sentiment_score > max_score:
      max_score = sentiment_score
      most_positive_tweet = tweet_text


    elif sentiment_score < min_score:

      min_score = sentiment_score
      most_negative_tweet = tweet_text
    
    else:
      pass

    username = tweet_dict["user"]["name"]
    mosttweets(username)




user_with_most_tweets = max(zip(dict1.values(), dict1.keys()))[1]




    #print(f"sentiment_score ={sentiment_score}")
    
    ################################
    # Your code should do the following:
    #   1. Keep track of the number of tweets
    #   2. Keep track of the number of positive and negative tweets
    #   3. Keep track of the user that tweet the most
    #   4. Keep track of the total number of unique users
    #   5. Keep track of the average number of tweets per user (how many tweets does each user make, on average)
    #   6. Keep track of the most positive and negative tweets.
    
    # YOUR CODE HERE
    
    ################################

# NOTE: You may need to have code after the for loop, depending on your implementation instead of everything being inside it.
# CODE HERE (Maybe, depending on your implementation)

twitter_dataset.close()


total_number_of_users = len(dict1.keys())


average_number_tweets_per_user =  total_number_of_tweets / len(dict1)

# %%
print(len(dict1.keys()))
# Out:
# 260270

# %%
print("Total Number of Tweets: {}".format(total_number_of_tweets))
print("Total Number of Positive Tweets: {}".format(total_number_of_positive_tweets))
print("Total Number of Negative Tweets: {}\n".format(total_number_of_negative_tweets))
print("Total Number of Neutral Tweets: {}\n".format(total_number_of_neutral_tweets ))


print(f" total = {total_number_of_positive_tweets + total_number_of_negative_tweets + total_number_of_neutral_tweets }")

print("Most Positive Tweet")
print(most_positive_tweet)
print()

print("Most Negative Tweet")
print(most_negative_tweet)
print()

print("Total Number of Users: {}".format(total_number_of_users))
print("Average Number of Tweets per User: {}".format(average_number_tweets_per_user))
print("User with the most tweets: {}".format(user_with_most_tweets))



print("sum",sum(dict1.values()))
# Out:
# Total Number of Tweets: 737153
# Total Number of Positive Tweets: 178205
# Total Number of Negative Tweets: 163502
#
# Total Number of Neutral Tweets: 395446
#
#  total = 737153
# Most Positive Tweet
# @thechew @JoAnnaLGarcia @KevinProbably Such amazing #'s of precious people fed in #PuertoRico by delicious, heartfelt work of @chefjoseandres &amp; friends. Also, top efforts by talented chefs towards precious people in #winecountryfires area. #northbayfires  Wish you'd have reported on it more. #SF #SonomaStrong
#
# Most Negative Tweet
# @realDonaldTrump LIAR LIAR LIAR LIAR LIAR LIAR LIAR LIAR LIAR LIAR LIAR LIAR LIAR LIAR LIAR LIAR LIAR LIAR LIAR LIAR LIAR LIAR #PuertoRico #PresidentLoco
#
# Total Number of Users: 260270
# Average Number of Tweets per User: 2.832262650324663
# User with the most tweets: Noti Puerto Rico🇵🇷
# sum 737153

# %% [markdown]
# The lines below give example inputs and correct outputs using asserts, and can be run to test the code. Passing these tests is necessary, but **NOT** sufficient to guarantee your implementation is correct. You may add additional test cases, but do not remove any tests.

# %%
assert(isinstance(total_number_of_tweets, int) or isinstance(total_number_of_tweets, float))
assert(isinstance(total_number_of_positive_tweets, int) or isinstance(total_number_of_positive_tweets, float))
assert(isinstance(total_number_of_negative_tweets, int) or isinstance(total_number_of_negative_tweets, float))
assert(isinstance(most_positive_tweet, str))
assert(isinstance(most_negative_tweet, str))
assert(isinstance(user_with_most_tweets, str))
assert(total_number_of_tweets == 737153)
print("Assert finished successfully!")
# Out:
# Assert finished successfully!

# %% [markdown]
# ## Exercise 7 (2 points)
#
# For this exercise, you will perform manual analysis of the predictions. Modify the code to load the tweet text, then answer the questions below.

# %%
import json
twitter_dataset = open('/content/drive/MyDrive/Colab Notebooks/puerto-rico.jsonl', 'r')

num_tweets_to_print = 20

num_tweets = 0

for row in twitter_dataset:
    num_tweets += 1
    tweet_dict = json_string_to_dictionary(row)
    
    ###############################
    # YOUR CODE HERE
    tweet_text = tweet_dict["full_text"]  # MODIFY THIS LINE TO GET THE "full_text" from the tweet_dict    
    ###############################
    
    num_pos_words = count_sentiment_words(positive_words, tweet_text, True)
    num_neg_words = count_sentiment_words(negative_words, tweet_text, True)
    
    sentiment_prediction = predict(num_pos_words, num_neg_words)
    
    print("Tweet {}: {}".format(num_tweets, tweet_text))
    print("Tweet {} Prediction: {}".format(num_tweets, sentiment_prediction))
    print()
    
    if num_tweets == num_tweets_to_print:
        break
    
twitter_dataset.close()
# Out:
# Tweet 1: RT @TheSWPrincess: @bri_sacks To find out how to help, visit the site below. Virgin Islanders are not getting the media attention that #Pue…
# Tweet 1 Prediction: neutral
#
# Tweet 2: I have yet to be able to express my thoughts without expletives about @realDonaldTrump + Hurricane Maria recovery #PuertoRico
# Tweet 2 Prediction: positive
#
# Tweet 3: RT @TalbertSwan: @TaIbertSwan @realDonaldTrump “Sire, the people don’t have power, food, or water!”
#
# #Trump: “Let them eat paper towels!”…
# Tweet 3 Prediction: neutral
#
# Tweet 4: RT @NYPDSpecialops: #NYPD ESU K9 “Harley” &amp; “Nash” deployed as part @fema NY-TF1 have been hard at work assisting in the #PuertoRico rescue…
# Tweet 4 Prediction: neutral
#
# Tweet 5: RT @StarrMSS: .@elvisduran gave 30K to @Bethenny to charter  plane to bring supplies to #PuertoRico #HurricaneMaria. He also gave 100K to @…
# Tweet 5 Prediction: neutral
#
# Tweet 6: RT @ericbolling: When will @realDonaldTrump catch a break from fake news outrage? Very unfair slams over #PuertoRico visit.
# Tweet 6 Prediction: negative
#
# Tweet 7: FCC approves up to $77 million to restore communications after hurricane https://t.co/hn0WqJiE9T #WonkAmerica https://t.co/m6P6RvDkZi
# Tweet 7 Prediction: neutral
#
# Tweet 8: "@daddy_yankee,#PuertoRico native,to #Donate $250,000 to #Habitat &amp; raise $1.5+ #Million!"❤
#
# https://t.co/32kjy93dNZ
# https://t.co/15bza8gjW0
# Tweet 8 Prediction: neutral
#
# Tweet 9: RT @ericbolling: When will @realDonaldTrump catch a break from fake news outrage? Very unfair slams over #PuertoRico visit.
# Tweet 9 Prediction: negative
#
# Tweet 10: RT @chefjoseandres: Forget politics forget pundits. What I have seen in #PuertoRico is people coming together, sacrificing 2 serve. This is…
# Tweet 10 Prediction: neutral
#
# Tweet 11: RT @mercycorps: Our neighbors in #PuertoRico are resilient, but they need our help to recover + rebuild. We invite you to join us.
#
# https:/…
# Tweet 11 Prediction: positive
#
# Tweet 12: RT @StopTrump2020: At least 34 dead - #Trump blames #PuertoRico for #FEMA not having enough money.  #SAD! https://t.co/DHuW7xGlOY
# Tweet 12 Prediction: neutral
#
# Tweet 13: RT @SamaritansPurse: With your support, our disaster response team continues to bring emergency relief to families in #PuertoRico. https://…
# Tweet 13 Prediction: negative
#
# Tweet 14: RT @usairforce: 4 @USARMY Pave Hawks, 4 pallets of search &amp; rescue gear, 1 ATV and 39 search &amp; rescue passengers aboard a C5 headed to #Pue…
# Tweet 14 Prediction: neutral
#
# Tweet 15: RT @RoseAnnDeMoro: RNRN and @AFLCIO send 300+ volunteers to #PuertoRico: union nurses, construction and transportation workers fly out toda…
# Tweet 15 Prediction: neutral
#
# Tweet 16: RT @daddy_yankee: I know the reconstruction of my home island will requiere long-term solutions. - go to the link and help me raise more mo…
# Tweet 16 Prediction: neutral
#
# Tweet 17: RT @Jenniffer2012: Thanks from my heart to @FLOTUS for your caring and your commitment to help. #PuertoRico 🇺🇸🇵🇷 https://t.co/p8fkXfKbXd
# Tweet 17 Prediction: positive
#
# Tweet 18: RT @RichardMadan: Here is President Trump tossing paper towels at hurricane victims in #PuertoRico https://t.co/JjLMRNFcAt
# Tweet 18 Prediction: positive
#
# Tweet 19: RT @JimmyPatronis: I’m deploying law enforcement assets to join @fdlepio, @FLHSMV and @MyFWC to help in #PuertoRico after #Maria: https://t…
# Tweet 19 Prediction: neutral
#
# Tweet 20: RT @ExDemLatina: .@CarmenYulinCruz is a Lying policial Corrupt hack!
# She has time to make another shirt for media rounds. #PuertoRico #San…
# Tweet 20 Prediction: negative

# %% [markdown]
# Complete the following tasks:
#
# - Manually annotate all of the tweets printed above. This is your interpretation. We want to understand how accurate the predictions are at the tweet-level:
#    1. Tweet 1 neutral
#    1. Tweet 2 positive
#    1. Tweet 3 negative
#    1. Tweet 4 Negative
#    1. Tweet 5 postive
#    1. Tweet 6 negative
#    1. Tweet 7 postive
#    1. Tweet 8 Positive
#    1. Tweet 9 negative
#    1. Tweet 10 positive
#    1. Tweet 11 positive
#    1. Tweet 12 negative
#    1. Tweet 13 positive
#    1. Tweet 14 positive
#    1. Tweet 15 positive
#    1. Tweet 16 neutral
#    1. Tweet 17 positive
#    1. Tweet 18 negative
#    1. Tweet 19 positive
#    1. Tweet 20 negative
#
# - How many of the predictions are right or wrong compared to your annotations?
#     - Answer Here I observed only 10 predictions are right compared to my annotations
#
#
#
#
# - Do you see any major limitations of lexicon-based classificaiton (i.e., making sentiment predictions using individual words)? Use your intuition, I will accept most answers, as long as it makes some sense. Please describe and provide examples below:
#
# Answer Here
#
# Just in case there is not before  all postive words , so totally sentence is negative , but it positive score

# %% [markdown]
# ## Extra Credit (2 points)
#
# For this exercise, you should use a different dataset (email me if you want me to share a dataset with your directly, or you can use your own---see below for dataset resources) and analyze it with a different (non-sentiment) lexicon. You can complete the same analysis as above, or do something different as long as you make use of a new lexicon and a new dataset. Notice some lexicons only have one class, or more than 2 classes. The processing will be slightly different. Feel free to ask how this can be done via Slack.
#
# Possible lexicons:
# - Hate speech and offensive language lexicons:
#     - https://github.com/steve050798/hate-speech-and-offensive-language/raw/master/lexicons/hatebase_dict.csv
#     - https://www.cs.cmu.edu/~biglou/resources/bad-words.txt
# - Emotion Lexicon:
#     - https://saifmohammad.com/WebPages/NRC-Emotion-Lexicon.htm#:~:text=The%20NRC%20Emotion%20Lexicon%20is,were%20manually%20done%20by%20crowdsourcing.
#         - Note that this lexicon has more than two classes. Message me for discussion about how to handle this.
#
# You may use one of the lexicons above or another non-sentiment lexicon of your choice. I may allow another sentiment lexicon if the new analysis is interesting; however, email me before doing this. An example would be using a Spanish sentiment lexicon to analyze Spanish text, or doing a different analysis than the one abouve (e.g., anayzing sentiment over time).
#
# Where to look for new data?
# - https://www.kaggle.com
# - https://www.docnow.io/catalog/ (Some datasets contain the text, not just tweet ids). If you have something specific you want, I can grab it for you using my developer account.
# - Google :). You do not need to use tweets.
#
# You can pull new data from Twitter, but you will need to create a developer account. The easiest way to pull new data is via the use of Twarc (https://github.com/DocNow/twarc).
#
# Finally, when you submit, I don't need to have your data, just make sure to provide a couple of examples, a link to the data (if available), and make sure all of the output of your code is printed with the output so I can analyze it.

# %%
# Write and document your code here
"""
offensive language Data set from kaggle  Meet in your office and downloaded dataset,

so i used bad words , i checked badwords in tweet its offensive, and also

find out no of bad words in each tweet

find out the max offensive tweet, and also printed out that tweet 


"""
# Out:
# '\noffensive language Data set from kaggle  Meet in your office and downloaded dataset,\n\nso i used bad words , i checked badwords in tweet its offensive, and also\n\nfind out no of bad words in each tweet\n\nfind out the max offensive tweet, and also printed out that tweet \n\n\n'

# %%
# !wget https://github.com/steve050798/hate-speech-and-offensive-language/raw/master/lexicons/hatebase_dict.csv
# Out:
# --2022-10-25 21:49:01--  https://github.com/steve050798/hate-speech-and-offensive-language/raw/master/lexicons/hatebase_dict.csv
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/steve050798/hate-speech-and-offensive-language/master/lexicons/hatebase_dict.csv [following]
# --2022-10-25 21:49:01--  https://raw.githubusercontent.com/steve050798/hate-speech-and-offensive-language/master/lexicons/hatebase_dict.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14502 (14K) [text/plain]
# Saving to: ‘hatebase_dict.csv’
#
# hatebase_dict.csv   100%[===================>]  14.16K  --.-KB/s    in 0s
#
# 2022-10-25 21:49:01 (100 MB/s) - ‘hatebase_dict.csv’ saved [14502/14502]

# %%
# !wget https://www.cs.cmu.edu/~biglou/resources/bad-words.txt
# Out:
# --2022-10-25 21:49:01--  https://www.cs.cmu.edu/~biglou/resources/bad-words.txt
# Resolving www.cs.cmu.edu (www.cs.cmu.edu)... 128.2.42.95
# Connecting to www.cs.cmu.edu (www.cs.cmu.edu)|128.2.42.95|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11169 (11K) [text/plain]
# Saving to: ‘bad-words.txt’
#
# bad-words.txt       100%[===================>]  10.91K  --.-KB/s    in 0s
#
# 2022-10-25 21:49:02 (159 MB/s) - ‘bad-words.txt’ saved [11169/11169]

# %%
with open("/content/bad-words.txt") as infile:
  list_badwords =[]
  for word in infile:
    list_badwords.append(word.strip("\n"))

# %%
import csv

with open('/content/drive/MyDrive/Colab Notebooks/labeled_data.csv') as csvfile:
  reader = csv.DictReader(csvfile)
  dict1 ={}
  High_count = 0
  high_tweet = ""
  row_counter = 1
  for row in reader:
    count = 0
    for word in list_badwords:
      if word in row["tweet"]:
        count = count + 1

    dict1[row_counter] = count

    if count > 0:
      print( "offensive= ", row["tweet"])
      
    row_counter = row_counter + 1
# Out:
# Streaming output truncated to the last 5000 lines.
# offensive=  RT @takeyaah: when his hoes thought it was over: http://t.co/jhaOcX1MTd
# offensive=  RT @tanajiamonay_: i hate hype ass bitches, like ... it's too early for you to be all loud; sit tf down somewhere.
# offensive=  RT @tanaka_callen: @t_ndyy awwww my niggar thank you so much sure means a lot &#9825;&#9825;
# offensive=  RT @tanishalixpussy: no need to compete with other women there's only one of me, and shit... im that bitch
# offensive=  RT @taylor_TM: @PacmanJonez @PhilWOTG you the whitest person on my TL but you always so ghetto. Im sick of it
# offensive=  RT @taylorcaniff: I wear beanies all winter long! So no bandanas till summer&#128525;
# offensive=  RT @taylorcaniff: I'm having a date at Yankee Field then getting kiss cam.. #bucketlist
# offensive=  RT @taylorlopez96: &#8220;@harleighpurolla: You are the biggest two faced bitch I have ever met.&#8221; You won't @ her
# offensive=  RT @taylormrake: People beg to see women's bodies but the minute they're seen that woman is now a hoe oh okay
# offensive=  RT @taylorrDiane: When a sideline hoe gets mad, BITCH SHUT UP! You was okay with being second ALL this time, now all of sudden it's a probl&#8230;
# offensive=  RT @taymaeGOTEM: Bitches tweets be like...
#
# "I wanna suck some dick &#127814;"
#
# then be like...
#
# "&#9995; Chill it's just a song! "
#
# bitch what song is&#8230;
# offensive=  RT @taymy_: I be so confused when y'all be tweeting "I wanna bitch that can roll my weed &amp;smoke all night with" like wtf kind of standards &#8230;
# offensive=  RT @taypaynay: Little bitch
# offensive=  RT @taysymonee: @1inkkofrosess that hoe so icy&#128557;&#128293;
# offensive=  RT @taysymonee: Some of you hoes got so much to say with so little&#128134;
# offensive=  RT @tbhbooty: Latina pussy be like http://t.co/VORy1vgH4U
# offensive=  RT @tbhjust: "what are you twelve"
#
# yeah on a scale of one to ten
#
# bitch
# offensive=  RT @tbhjuststop: my score on flappy bird is higher than the broncos score right now
# offensive=  RT @tbhjustzach: why be negative when you can be positive fucking smile you beautiful bitch
# offensive=  RT @tcaputo44: Trust no bitch #wordsofadvice
# offensive=  RT @teapot: Stuff broke loose, must not panic and share GIF instead http://t.co/JL4GuIeJ84
# offensive=  RT @teeaduh: "so many hoes, it should be an ethnicity"
# offensive=  RT @teekaydont_GAF: @WestSideFlee out here sending hoes clean off fse !!!!&#128514;&#128514;&#128514;&#128514;
# offensive=  RT @tekiaa_: I wasnt put on earth for a bitch not to like me&amp; I damn for sure dgaffff &#128540;&#128076;
# offensive=  RT @terri_georgia: Charlie Crist Leads Rick Scott In a Florida Governor's Race Where Every Vote Will Matter http://t.co/FWUH5pVnjk
# offensive=  RT @tf_i_looklike: Bae: If I win you don't get no pussy tonight
#
# Me: Shiiiiiit... &#128514;&#128514; http://t.co/yUJJDMtDC4
# offensive=  RT @th3j35t3r: Prime suspect of #Foley murder is 23y/o British Jihadi who, wait for it ... "declared his allegiance to Anonymous'" http://t&#8230;
# offensive=  RT @thaboyrich: &#128073;&#128073;RT @NYSAnimal It used to be a shame to be hoe/prostitute, with social media they call it hustling lol
# offensive=  RT @thachosenkid321: @DonQuixtote he trash tbh #StartMikeVike
# offensive=  RT @thachosenkid321: If I were to say be my girlfriend would you believe that I dropped all my hoes for you?
# offensive=  RT @that1kidzi: Ohioans clowned on Kid like, "It's sooo warm here! What the fuck is wrong with Minnesota?" Well that bitch Karma teamed wit&#8230;
# offensive=  RT @that_nigga_shad: @Visually_Gifted They sound like soulless cunts
# offensive=  RT @thatgirlran: &#8220;If your 15/16 ACT like your those ages not like your 20. Its not cute.&#8221; That awk moment when I thought this tweet was abo&#8230;
# offensive=  RT @thatsryann: If you think your mans cheating, you take him to that bitches house and see if his wifi connects&#128074;
# offensive=  RT @theARTofTriLL: Dolph in this hoe... Bout to rock dj holiday show!!!! #memphis
# offensive=  RT @theChefBoyRD: @victoriaaa_lee @anniespringer_ ew she's so ugly who is that hoe
# offensive=  RT @theChefBoyRD: My pussy popz Severely https://t.co/15IOQ7M0KF
# offensive=  RT @theHIGHESTpeak_: Flavaaaaa in ya ear, that hoe live lol
# offensive=  RT @theHIGHESTpeak_: Ya lil dumb ass bitch ian fwy
# offensive=  RT @theROYALlife: Ha ha real name is Ha'Sean &#128530;&#128530; where y'all get these ghetto ass names from?
# offensive=  RT @theSTRANGEST: ready to make today my bitch.
# offensive=  RT @the_blueprint: in the trash, i hope. RT @ComplexMag @BigSean just dropped four new songs
# offensive=  RT @the_ironsheik: Alex Rodriguez you lucky only the Ryan Dempster hit you. I going to get my camel to break your neck you son of a bitch
# offensive=  RT @the_ironsheik: Justin Bieber win Oscar for suck my balls you dead dog midget dick son of a bitch
# offensive=  RT @the_ironsheik: My #tbt I learn the English from that jabroni big bird but I break his fucking neck http://t.co/vDpIq8Zuxo http://t.co/4&#8230;
# offensive=  RT @the_ironsheik: Wake up you dumb son of a bitch
# offensive=  RT @the_ironsheik: hello @TheBatman you are now official big time pussy
# offensive=  RT @the_thrillx3: Sarah burkes pussy b like http://t.co/HpXUDcuNEq
# offensive=  RT @theafr0dite: then u have the annoying "HIT ME I DARE YOU" ass bitches always tryna test a big ass 6ft linebacker ass dude.. girl if you&#8230;
# offensive=  RT @thebootycluh_: &#8220;@_xoxoMOOKY: Why do niggas settle for easy bitches ? Like don't y'all wanna bitch that challenges you to better yoursel&#8230;
# offensive=  RT @thebrandymedel: Every bitch got a nigga that she gone always fuck with. No matter what. &#128152;
# offensive=  RT @thecoreyholcomb: All these bitches somewhere coughing like a mug http://t.co/Pow2SHkwIz
# offensive=  RT @thecoreyholcomb: ESPN has Jason Whitlock on PTI ass kissing for mister Charlie to justify the bullshit the Eagles did to D. Jackson
# offensive=  RT @thecoreyholcomb: Every man can't have a bad bitch. But in this country if you got 100$ cash &amp; r willing to go where poverty roams, you &#8230;
# offensive=  RT @thecoreyholcomb: Every time you sleep with two women in a day it proves this country has a problem educating bitches about their self w&#8230;
# offensive=  RT @thecoreyholcomb: If your man is happy in his next relationship your fucked up ways are a blessing bitch
# offensive=  RT @thecoreyholcomb: It's a got damn shame bitches wit raw ass dick sucking skills are not wifey material.
# offensive=  RT @thecoreyholcomb: Long finger dike hoes be pulling off their gloves instead of winking at bitches they trying to suck
# offensive=  RT @thecoreyholcomb: No man has ever aborted a baby even if he have her $ on it. Abortion bitches will soon meet god &amp; they baby to face th&#8230;
# offensive=  RT @thecoreyholcomb: People who r mentally stable know when to beat their kids &amp; when to talk to them. Clubs hoes &amp; "stop by dads" should n&#8230;
# offensive=  RT @thecoreyholcomb: The WNBA superstars can suck pussy while on top of da world but when they stop playing &amp; da thousands r gone they sett&#8230;
# offensive=  RT @thecoreyholcomb: This bitch wit a baby ask me to switch seats so the family could be together. I said "bitch my family wasn't together?&#8230;
# offensive=  RT @thecoreyholcomb: Twitter family, I promise to put my tour schedule up today as soon as I have this pussy hustlin girl I pay for service&#8230;
# offensive=  RT @thecoreyholcomb: When gay girls suck pussy from a bitch who just took a plan B pill the other day that means the munching hoe ate plans&#8230;
# offensive=  RT @thecoreyholcomb: You are who you kick it wit y'all. Check yo squad- if busters &amp; blameamotherfucker ass bitches surround U it's twice a&#8230;
# offensive=  RT @thecrewfinest: "@187XO_: Me and ma niggah @thecrewfinest In the Func fucccccccked upppppp &#128514;"I'm Here On!!!
# offensive=  RT @thefrogod: Dat shit trash
#
# &#8220;@ComplexMag: A shirt inspired by @Drake's emoji tattoo. Pre-order now: http://t.co/VAuLGcpkIS http://t.co/h&#8230;
# offensive=  RT @thegame: RT @sean_locs93: The Game Beats 40 Glocc in LA (Full Video) http://t.co/80lf7HvsWm via @youtube - this bitch 40 cop can't be s&#8230;
# offensive=  RT @thejokerxo: &#128064;&#127939; "@Weed_Cloudz: Does SZA have freckles on her pussy too?"
# offensive=  RT @thejudyann: And if you ain't a hoe, get up out my trap houseeee!
# offensive=  RT @thelibraicon: &#128514;&#128514;&#128514; RT @WeNotSocks: &#128557;&#128557;&#128557; RT @IntenseDesire: Bow wow look like the stress of saving a hoe is wearing him down http://t.co/S&#8230;
# offensive=  RT @therealQuilly: A bitch will fuck wit a dead beat dad as long as he cuttin her checks&#128546;
# offensive=  RT @thereal_EMandM: @red_is_raw so is your pussy lmao
# offensive=  RT @thereal_EMandM: Settling down is for pussies
# offensive=  RT @thereal_EMandM: Yankee Doodle had a farm. Cotton farm
# offensive=  RT @therealelp: from @CNN tonight: " N word or cracker...which is more offensive?". probably the one you won't spell out, you fucking hacks&#8230;
# offensive=  RT @therealiman: The price of pussy in Toronto has now declined to one Henessey bottle and a quarter pounder combo with large fries.
# offensive=  RT @thesexiertwin: Making today my bitch &#128520;
# offensive=  RT @thewayoftheid: Viola Davis sans wig is still stuntin on you hoes in the most classically beautiful way. #HTGAWM
# offensive=  RT @thewhite_gucci: This bitch just blew my high and i was high off all of these drugs
# offensive=  RT @theyLOVEblaq_: joseline did not sneak athea , if a bitch you dont like coming at you like that &amp; you still sit yo ass onnat couch THATS&#8230;
# offensive=  RT @theyallTATIfans: &#8220;@BeeGuwop: I told you to unfollow that bitch but you ain't wanna listen Barbie http://t.co/sw3rkoCW1c&#8221; &#128079;&#128079;&#128079;&#128514;
# offensive=  RT @theycallmenavy: @royaltyclubvp @Aswaad88 worse yet u meet a bird with a nice ras and you're like "something about u looks familiar" lol&#8230;
# offensive=  RT @theyoungdread: Words go from babe to bitch, I love you to I hate you, I need you to forget you, you're my everything to you're nothing.
# offensive=  RT @thiizz_: &amp; fuck these bitches
# offensive=  RT @thinksarcasm: My music taste goes from ghetto black girl to depressed white girl.
# offensive=  RT @thirlrection: I will fight a bitch for Austin that's my gringo right there ain't no one messing with my white chocolate drop
# offensive=  RT @thisdayinmetal: Apr 29th 1997 @WASPOfficial released the album "Kill.Fuck.Die" #TakeTheAddiction #MyTorturedEyes #WASP #HeavyMetal http&#8230;
# offensive=  RT @thotbucket: This kid is wearing HUF socks and a Don't Sweat My Swag sweatshirt. And I'm like leave some pussy for the rest of us dude
# offensive=  RT @thoughtkendalI: dumb bitch ruined a perfectly good sweater http://t.co/lk8W8jjglI
# offensive=  RT @thtsher__: if ya bitch mad tell ha I'll put ha own &#128176;
# offensive=  RT @tianaroseee_: Mary Jane my only bitch
# offensive=  RT @tiaramescudi: I hate when bitter bitches try to take away someone's happiness.
# offensive=  RT @tiathegawd: bitches be trying the wrong bitches &amp; don't even be knowing..
# offensive=  RT @tic14tac: Guys be like "Man, fuck that bitch!" &#128563; But deep inside, they miss that "bitch", still love that "bitch", &amp; want that "bitch" &#8230;
# offensive=  RT @ticiaverveer: Royal city of the Kushite kings at Meroe (Sudan),near River Nile.It was the seat of the rulers who occupied Egypt http://&#8230;
# offensive=  RT @tictacsforsex: If your girlfriend doesn't like that bitch. You don't talk to that bitch.
# offensive=  RT @tightgripp: this bitch just said "I hope it snows like hell this summer " &#128563; now How in the actual FUCK do you expect that to happen?
# offensive=  RT @tigolbittiesxo: No bitch u were not born with 7 pounds of sephora and MAC on ya face, that's not ya natural face
# offensive=  RT @timbvtcher: Old soul? More like young bitch.
# offensive=  RT @tinatbh: rt if u a broke bitch with expensive taste
# offensive=  RT @tinykissable: Only low self esteem niggas walk around braggin about bitches he fucked! They have something to prove to ppl
# offensive=  RT @tishforprez: that pointy nail game is for da birds.
# offensive=  RT @tishforprez: you had me at "eating pussy".
# offensive=  RT @titaaaR15: Dumb bitch
# offensive=  RT @tj_curtin: A birds eye view of today's #harvest14 activities. Thanks @BrentJFF for the great camera work! http://t.co/RgETR4tV4S
# offensive=  RT @tmaeleen: this bitch just blew my high &amp; i was off all of dese drugs...
# offensive=  RT @tmoney_presa: *when bae sings "it ain't nun to cut that bitch off" with too much enthusiasm* http://t.co/CN0Vtrk8DA
# offensive=  RT @tnicolle_rauzi: We always bitch about the opposite sex when we're equally just as scandalous. Not all, but a large sum. Hypocrisy at it&#8230;
# offensive=  RT @toddknife: Full @weakenednachos set (except the last song) from Southern Darkness Fest last month. Who's the ape on guitar? https://t.c&#8230;
# offensive=  RT @tokmetzis: Dreigdwergen, haatsmurfen en de Roze Khmer: hoe Twitter een slagveld werd https://t.co/lhVKkkHQDF via @decorrespondent
# offensive=  RT @tolkienproverb: Fairy tale does not deny the existence of sorrow and failure...
# offensive=  RT @tommy_kayyy: Aye little bitch y'all niggas hirin? &#128514;&#128514;&#128514; https://t.co/F0nTMVCDio
# offensive=  RT @tommyjaster: Where da hoes at... C'Mon thru at Hatchy's in Utica TDT about to rock dis biiaaaatch. #TDTHoe #teamspade #highgang
# offensive=  RT @tomtomorrow: Have their been any reports of an aerosolized virus that turns apes intelligent? Seems like that kind of day.
# offensive=  RT @tonymoore: Found cheese cracker sandwiches in the cabinet, a year expired. Ate them anyway. If I die tonight, these will be the worst l&#8230;
# offensive=  RT @tonyrobbins: Piers Morgan to Charlie Sheen: &#8220;You were taking Cocaine&#8230;&#8221; Charlie Sheen: &#8220;I wasn&#8217;t taking it. I had to pay for it.&#8221; via ...
# offensive=  RT @toodope_bro: If a nigga can tell hoes he's taken , he's a real nigga .
# offensive=  RT @toujoours: could never kiss up to a bitch or follow up being someone. not my cup of tea , you hoes look foolish
# offensive=  RT @townhallcom: Charlie Crist Refuses To Back Down From Race-Based Attack On GOP http://t.co/zSHn94OK9S
# offensive=  RT @tr4pb0y: when the pussy so good &amp; u forget to pull out http://t.co/653Te4sUhr
# offensive=  RT @trackinBlackKev: @MichelleDBeadle shut the fuck up dumb bitch
# offensive=  RT @tracksideonline: There will be track sweeping during this yellow.
# offensive=  RT @transtrenda: Okay okay but. Trans birds
# offensive=  RT @trapfuI: i hate a "i don't text first" type bitch
# offensive=  RT @trapgodcon: Squad up bitch nigga @Ride907 @terryak907 @thomas_olmstead http://t.co/g3BoK10PjZ
# offensive=  RT @trapgrampa: I fucked ur bitch after I got bingo
# offensive=  RT @traphouseryan: "Damn girl that pussy talkin" &#128128;&#128557;&#128557; Im keeled over nigga
# offensive=  RT @traplord_: Ridin round blowin loud, fuck hoes by the crowd. RT @1TAKEHOV: Lil Reese's verse on My Lil Niggas is a str8 hip hop classic
# offensive=  RT @trapwithRonnie: These Thots keep saying all niggas want is pussy&#128049;&#128530;....Well bitch wtf else does your broke, non cooking, ass have to off&#8230;
# offensive=  RT @trayn1gga: 1? Smh &#128514; RT @WombRaider773: &#8220;@HOFSportsTalk: Yoo &#128514;&#128514; http://t.co/4SqZ7Tvp4v&#8221;
#
# What a fuckin EGO bust. #pussy
# offensive=  RT @trayn1gga: Alabama is overrated this yr the last 2 weeks has shown too many chinks in their armor WV gave them hell too
# offensive=  RT @trentlilweezy: "you are trash"
#
# me: http://t.co/nX2tqImO2a
# offensive=  RT @treszTHEbest: It's all they know RT @SMCo71: you bitches never gonna b happy following these social sites
# offensive=  RT @trevso_electric: You want a hot body? You want a Bugatti? You better be born into wealth, bitch.
# offensive=  RT @treyjohnican: Possum a hoe ..
# offensive=  RT @treymcgruder233: @22EdHam what you still doing up my nig
# offensive=  RT @trianglesoul: I wanna eat weed brownies but then I ask my self if I really wanna spend countless hours watching a documentary on sea tu&#8230;
# offensive=  RT @trillest_304: i wish they made a hoe fax .
# id be like show me the hoe fax before dateing a girl .
# offensive=  RT @trillmnded: bitches will fuck a nigga with money knowing he ain't buying her shit. but won't fuck a broke nigga that would give her his&#8230;
# offensive=  RT @trillycjuicy: I'm really chill. I talk to everyone, I'm far from being a stuck up bitch.
# offensive=  RT @tristabee: you used to be the shit but now you ain't shit bitch
# offensive=  RT @trix2343: @ZitlalyL @Vic_Manzan0 he's a beaner not a nigga
# offensive=  RT @trrvvv: Some these bitches got birkins and don't even have cars on the island.. Let alone furniture
# offensive=  RT @truudayyb: Where'd you get the beauty scar tough guy, eating pussy .. #Scarface
# offensive=  RT @trvpgxdx: Jen: Bitch Daquan dropped your kids off today
#
# Keisha: Bitch I don't got kids
#
# Jen: not no more bitch I swallowed em http://t&#8230;
# offensive=  RT @trvpunzill: $ &gt; these bitches
# offensive=  RT @trvvp_: These hoes got no chill http://t.co/lc5GsfOVXS
# offensive=  RT @tryna_be_famous: Like, when you're a hoe, how do u sleep at night?
# offensive=  RT @tsgnews: UPDATE: Collegian dressed as yellow Teletubby will face charges for break-in, theft of Chinese food leftovers... http://t.co/S&#8230;
# offensive=  RT @tuitillidie: Icepick punk bitch blood in the mosh pit
# offensive=  RT @tumblrfunniest: When I throw away paperball perfectly into the trash can: http://t.co/215E0H0PS9
# offensive=  RT @tupac_taughtmeh: "@DivaMonRoe2uHoE: Somebody find this bitch &amp; fuck her. She ain't had no good dick fucking With this fat nigga. http:/&#8230;
# offensive=  RT @tupactopus: bad bitches get in free night at weenie hut jrs
# offensive=  RT @tupactopus: hoes on my jitterbug
# offensive=  RT @tupactopus: need a bad bitch who knows how 2 treat a pokemon master right
# offensive=  RT @turk_jt12: That bitch ain't loyal.
# offensive=  RT @twaimz: i have never screamed so much like a little bitch just from A FUCKING VIDEO GAME IM LEAVING EARTH I-G-G-BYE
# offensive=  RT @twayne1010: Charles Manson's fiancee will have a difficult time planning their honeymoon. Charlie can't surf.
# offensive=  RT @twerkn4boba: " fuck you say bitch? I will kill you " http://t.co/3EiGzh6Q13
# offensive=  RT @twincitytyson: bitches hanging in the salty spatoon, tweetin "y can't I find a good guy :-(:-(:-("
# offensive=  RT @tyler_yost: You guys are all the best @brownboy_U @Yojhan174 @caitnicole3 @alexiscarfield @CiCi_Phi love you nig nogs #indyfam
# offensive=  RT @tylerfucks: recent studies have shown that ur a lil bitch
# offensive=  RT @tylergposey: Happy teen wolf! Here's me with @IanBohen getting ready to bitch slap a berzerker http://t.co/ZChBqXFA0g
# offensive=  RT @tyleroakley: Merry Christmas, everyone! Unless you're a fucking bitch then literally just go.
# offensive=  RT @tylerschuster88: How much coke did Charlie sheen do?.. Enough to kill two and a half men I guess
# offensive=  RT @uMadddt: #FixItJesus &#128588;
# &#8220;@MyAssholePops: This bitch is the nugget filling at McDonald's http://t.co/QBdbMsHjG7&#8221;
# offensive=  RT @uMadddt: Claw that ass!
# @CoreysTweetnAss: when u see that bitch who was talkin shit on twitter in public... http://t.co/yyQ2d6JujD
# offensive=  RT @ugIycutie: one, two, three, four, how many niggers are in my store?
# offensive=  RT @uhfrocircus: This is the life nigger
# offensive=  RT @unanswerdverses: did that bitch ever get out of ludacris's way?
# offensive=  RT @unanswerdverses: what bitch tried to kill Kendrick Lamar's vibe?
# offensive=  RT @uncle_palacios: &#8220;@SheeeRatchet: "bitch ass nigga square up" &#128514;&#128514; http://t.co/UHkKKwsrDL&#8221; @CaelanG15
# offensive=  RT @uncledaddy69: @weakenednachos California's biggest retards. Don't forget about HOLY who just released an amazing EP.
# offensive=  RT @urbandictionary: @The2kGod nigger: A fully grown niglet http://t.co/HJKlNHDrWT http://t.co/x6y5XKKPMq
# offensive=  RT @urinnerdevil: ur typical twitter hoe http://t.co/YJE9LUnWVp
# offensive=  RT @useemitch: 1, 2, 3, 4... how many niggers are in my store, I knooooooow your stealing! &#128514;&#128514;&#128514;
# offensive=  RT @usmntHistory: On this #USMNT day 2014, the Yanks advanced out of the #GroupOfDeath despite a 0-1 loss to #GER.
# offensive=  RT @vackra_lognn: I don't know why I go on that pancake face bitchs twitter. She gets me tight every time
# offensive=  RT @vanluvz1: My body thought we'd get an extra hr sleep but my brain decided to wake up 2 hrs earlier.
# My brains a bitch.
# offensive=  RT @varepall: Charlie Rangel on GOP: They 'believe slavery isn't over' http://t.co/I8nolg9m6O
#
# RANGEL IS A FLAGRANT TAX EVADER AND RACIST
# offensive=  RT @veeveeveeveevee: If I was Obama Id call a press conference &amp; slit joe bidens neck on live tv just 2 show these crackers I mean business&#8230;
# offensive=  RT @velweb: Thank you One-A-Day for making your vitamins the size of a fucking Twinkie. I love giving myself the heimlich maneuver every mo&#8230;
# offensive=  RT @verkannt__: None of my bitches judge me they love me &#128524; don't think they would like me if i was any other way
# offensive=  RT @versacecum: bitches be like "&#9749;&#128056;" but still be in everybody's business
# offensive=  RT @versacecum: some girls be using halloween as an excuse to act like hoes and get away with it smh
# offensive=  RT @versaceezy: i aint gonna text first cus pride bitch
# offensive=  RT @versaceezy: if we date u don't even gotta worry bout me talking to other hoes cus I ain't got any
# offensive=  RT @versaceezy: she said &#8220;i want a man who can pick me up during sex&#8221; bitch you lucky i picked you up at all gas prices high as hell
# offensive=  RT @versaceezy: side hoe: let&#8217;s make us official
#
# me: https://t.co/Kfqy4ouFgo
# offensive=  RT @verseunanswered: Did that bitch from Frozen ever let it go?
# offensive=  RT @verseunanswered: Did those bitches from Frozen ever build a snowman?
# offensive=  RT @vexedmentals: draya really out catching a tan while her son looking out the window like the ikea monkey while everybody trick or treati&#8230;
# offensive=  RT @vickstar_isabel: "@kyleighhmariee: &#8220;@TezCapone: My type a bitch &#128525;&#128525;&#128553; https://t.co/Bz4yBovcfl&#8221;"
#
# Lmao yass
# offensive=  RT @vickyBeanMr: Girls "go talk to your other hoes" game too strong
# offensive=  RT @vickyBeanMr: We live In a world full of unloyal hoes &amp; ugly niggas asking for hugs
# offensive=  RT @vickyBeanMr: When u with yo main bitch and you see yo side bitch in public http://t.co/scmkp1nYGU
# offensive=  RT @vincestaples: In other news your bitch cook for me.
# offensive=  RT @vinehumor: Flappy bird is taking over my life. I can hear the bird crashing every time something goes wrong. https://t.co/kuLDr4mabp
# offensive=  RT @vinnycrack: this bitch got the itunes terms and conditions tattooed on her http://t.co/dHRVCNRR1H
# offensive=  RT @viper5816: Sen. Harry Reid Lists all the Things Republicans Have Blocked in the Senate http://t.co/bjoWvABwhi via @townhallcom
# He is ho&#8230;
# offensive=  RT @virleehol: @cbinflux Well we sure as heck know how to read. I'm reading the trash right now and almost everything I've heard on the web&#8230;
# offensive=  RT @vntonx: "suck my duck"
#
# thot: "lol looks like ur autocorrect changed dick to duck"
#
# "i meant what i said bitch" http://t.co/K9LV3mfX1m
# offensive=  RT @vodkapapixo: "@Weed_Cloudz: "6 God" by Drake is trash" thank you
# offensive=  RT @vodkapapixo: Black girls have never been into me. I guess cause I don't call them hoes, sell drug's or shoot niggas o well.
# offensive=  RT @w1LLiam_: @Whackko y'all boyz was fried! Fuck dat pussy nigga in the blue doe
# offensive=  RT @walkerkpt: Prediction- "Obama will leave the Democratic Party in shambles "&#128563; oh gosh, I hope so &#128591;&#128079;&#128074;&#128170;&#128077;payback really is a bitch
# offensive=  RT @walkinghashtag: "@dumbcollegefun: Mean girls are just honest bitches. #Truth" @JacklynAnnn
# offensive=  RT @walshnyc: Which World Cup Teams Are Jihadis Rooting For? http://t.co/ecU754zHKk @versharma @vocativ http://t.co/8z0B7ocMqP
# offensive=  RT @warningfragile: everyone always says girls are really bitchy, no. some boys are fucking inconsiderate bitchy cunts it is actually disgu&#8230;
# offensive=  RT @washingtonpost: China's bird flu outbreak: 3 good signs, 3 bad signs and 3 very bad signs http://t.co/v3n67Gs5Mw
# offensive=  RT @wastedsatan: Ane is a cunt
# offensive=  RT @waymoflydenu: Why y'all hoes in such a hurry to be single mothers?
# offensive=  RT @wb_kaylaa: Fake bitch : hey girl
#
# Me:&#128133; http://t.co/GDiiwRDgNO
# offensive=  RT @wcvbkelleyt: Just me or are there a lot of tweets from media tonight about election night food??!! For the record: cheese &amp; crackers @s&#8230;
# offensive=  RT @weakenednachos: last thought before bed: in '92 we had a "mock election" in 3rd grade and i voted for Perot. maybe i related to his rea&#8230;
# offensive=  RT @wegomakeit: pussy pussy pussy i smell ya frum bout a mile away&#128564;
# offensive=  RT @weirdstyle: I have 0 hoes lmfao
# offensive=  RT @whaddoyoumean: Too many bitches is shady
# offensive=  RT @whatupwxll: @VivaLaKash &#128514;&#128514;&#128514; got dhem hoes !
# offensive=  RT @whiskeyqueeen: niggas ain't shit but hoes with dicks
# offensive=  RT @whisperdispatch: Charlie wearing the 'Don't Tread On Me' flag pin? Every Dem should show up in Congress in 2015 wearing that @ESQPoliti&#8230;
# offensive=  RT @whitbreezy: Once I get a cold beer in my hand there ain't no mistakin who I am, I can't hide my redneck side
# offensive=  RT @whiteboytatted: Shout out to all you girls that wear those holy cross leggings but got a pussy thats full of sin
# offensive=  RT @whoThatBe_LAE: raising asia.... that lil bitch could dance bruh &#128514;
# offensive=  RT @whodatth0: &#8220;@AAAdontplayy: lmfao hicks https://t.co/kNa2U0D2o0&#8221;lmfao
# offensive=  RT @willgoes_ham: I love bad bitches that's my fuckin problem &#128527;
# offensive=  RT @willyroast2: Ratchet hoes wear flip flops that curl up and turned black like souls of slaves walked in them
# offensive=  RT @willyroast2: yo girl pussy stank @SoloExMachina This tweet stinks RT @willyroast2: There is no suck thing as a faithful bitch in Washin&#8230;
# offensive=  RT @wilw: Even shorter Charlie Sheen: "Your move, Mel Gibson."
# offensive=  RT @winkSOSA: "@AintShitSweet__: "@Rakwon_OGOD: Nigga messed with the wrong bitch &#128557;&#128514;https://t.co/5mNXKVAYot" &#128557;&#128557;&#128557;&#128557;&#128514;&#128514;&#128557;&#128557;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;"@Th_Real_Esco
# offensive=  RT @wintervphillips: *steals your bitch*
# offensive=  RT @wisdom_spewed: No, you stupid redneck, "Animal Husbandry" does NOT mean you can get hitched to your blue tick hound, Misty.
# offensive=  RT @wishfulll: Big booty bitches with... "@StagBeChillin: Ass RT @iDocLyfe: Tits"
# offensive=  RT @wittybigtwittys: I use the word cunt very loosely
# offensive=  RT @wizkhalifa: Currently taking over ur bitches brain with my creativity and wierdness.
# offensive=  RT @wizkhalifa: On the east coast there's colored hair everywhere.
#
# This must be the sweetest wave ever.
# offensive=  RT @wizkhalifa: Respect the man with vision and a gang of bitches to follow it.
# offensive=  RT @wizkhalifa: Share your feelings but if iss some hoe shit, keep it to yourself.
# offensive=  RT @wizkhalifa: Woke up sleazy. Im bout to make this day my bitch
# offensive=  RT @wleerpcv: My Chinese social media feed is in total hysteria over the onset of bird flu &amp; recent dead pigs in the river in #Shang ...
# offensive=  RT @wojtata: @NoneShallPass97 fuck you up fucking skank ass cunt
# offensive=  RT @wojtata: Huntley High School is the most retarded high school ever.
# offensive=  RT @woodpusha_: This bitch tried to give my dick a hickey
# offensive=  RT @woohdakidd_74: &#8220;@Shane_A1: Am I wrong fa laughin at dem niccas on 1st 48 who be cryin n the interrogation room&#8221;hell noooo&#128514;&#128514;&#128514;pussy ass n&#8230;
# offensive=  RT @woohdakidd_74: &#8220;@Shane_A1: I did use to buy 2 tees n wear both dem bitches at the same time&#8221;lame ass lol
# offensive=  RT @woohdakidd_74: &#8220;@Shane_A1: I'm steady hearin bout these suppose to be tuff street niccas gettin fuccd n dey ass smh gay boys&#8221;&#128561;&#128561;smh sad &#8230;
# offensive=  RT @woohdakidd_74: @Shane_A1 &#128514;&#128514;&#128514;they ain't een kno I was in that bitch
# offensive=  RT @worIdstarcomedy: When you're stressing over someone then realize you got hoes .. &#128514;&#128557;&#128175; https://t.co/PFmRDuHoXb
# offensive=  RT @worley_7: Enough with the mind fuck and pass me the fucking nachos, cunt.
# offensive=  RT @worst_B_ehavior: If you don't give your bf head you're a lame bitch and he's probably cheating on you with a bitch the suck his shit dr&#8230;
# offensive=  RT @wrongmusicvine: #MusicThatDoesntMatch These hoes aint loyal! http://t.co/prXCfleT2W
# offensive=  RT @wrongwaybennett: Only Southerners know the difference between redneck and white trash.
# offensive=  RT @wtfdawkins: Let's go Yankees
# offensive=  RT @wtfuxupjessie: A hoe is cool with being unclaimed and kept on the low so that people don't call her what she is. A hoe.
# offensive=  RT @wvjoe911: Gov Rick Scott Refuses To Debate Charlie Crist Because Of A Small Fan http://t.co/hKMfPnRukU
# offensive=  RT @wwwobert_: New avi thanks to b Oreo
# offensive=  RT @x2Pac_ThuGLorD: Whatever. No matter how many times kids fuck me over I will never become I pussy. I promise you that.
# offensive=  RT @xBrandi_: Only real bitches suck dick
# offensive=  RT @xCaramel_Jonesx: Don't be 32 on here and saying "all my friends and everyone I know has a baby".
#
# Well bitch. Life.
# offensive=  RT @xDSmooth: #shoutout to that niggah @1BookieG
# Go follow
# offensive=  RT @xDSmooth: @1BookieG remember that one bitch ass you ate out last week
# offensive=  RT @xDSmooth: @IzThat_xp @1BookieG lmao niggah this is twitter my Kenosha bitches can't be trained like my Florida bitches
# offensive=  RT @xDSmooth: @Mixxed_BreedXO @1BookieG this niggah was tripping over everybody
# offensive=  RT @xDSmooth: Damn my niggah side bitch got him making her a sandwich &#128514;&#128514;&#128514;
# offensive=  RT @xDSmooth: Free my niggah @1BookieG
# offensive=  RT @xDSmooth: I asked @1BookieG what's the definition of a preppy white girl and this niggah said Starbucks
# offensive=  RT @xDSmooth: I took yo job bitch @1BookieG
# offensive=  RT @xDSmooth: Nooo I left my papers in the basement n my niggah getting some cakes down there -.-
# offensive=  RT @xDSmooth: The way this niggah just flinched at this movie was #priceless @1BookieG
# offensive=  RT @xDSmooth: This niggah said her lips dry ass hell lmao &#128514;&#128514;&#128514;&#128514;
# offensive=  RT @xGingerAvenger: To that cunt who said she won't RT ppl who use foul language because it lacks intelligence... bitch, let me introduce y&#8230;
# offensive=  RT @xM_3Times: Yung nation- riot . Still bump that hoe
# offensive=  RT @xNikiaaa_: @1stBlocJeremiah damn where you on house arrest at ? &amp; yup in tht bitch like &#128080;&#128131;&#128527;
# offensive=  RT @xPoppinWheelies: &#8220;@1stBlocJeremiah: All y'all bitches corny lol&#8221;rt
# offensive=  RT @xPoppinWheelies: Lol the thirst be so real on dis bitch &#128514;
# offensive=  RT @xSALUTE_BADDAZZ: Well I just got conformation that is your body count is five or above, it's high and you a hoe &#128514;&#128514;&#128514;
# offensive=  RT @xTayGOTTII: &#8220;@__DatTootieGurl: @TaeFrmUTW @xTayGOTTII iont Like yall always talking. Not even tryna be funny thou rns&#8221;&#128514;&#128514;&#128514;&#128514; bitch I do&#8230;
# offensive=  RT @xTheMaddHatter: 9, 10 now you're having my twins. RT @polierburrr: 7, 8 get that pussy ate RT RT @R0SEADDAMS: you &#128298; http://t.co/WwSINeJ&#8230;
# offensive=  RT @xXxRAIDERCH1CKA: We all know dumb bitches like this http://t.co/dq9yKQFV
# offensive=  RT @x_Jimbo: Multi till I die bitch believe that...
# offensive=  RT @xenakix2243: Feeling the crisp fall wind spinning around me and watching the colorful leaves fall like rainbow colored raindrops slowly&#8230;
# offensive=  RT @xfleezus: cant turn a hoe into a housewife.
# offensive=  RT @xjayyandrew: I'm trynna find me a wifey type, not a hoe type.
# offensive=  RT @xleaaahh: &#8220;@1stBlocJeremiah: I want subway cookies&#8221; dem bitches do sound good rn&#128514;&#128551;
# offensive=  RT @xo_FCK_LOVE: "@HelloBrooklynn_: Not sparing no hoes&#128514; http://t.co/q3fskcY6L2" &#128175;
# offensive=  RT @xo_Jack: You can definitely tell who's a whore by what bitches wear when it's slightly warm out.. &#128581;&#9995;&#128567;
# offensive=  RT @xobeauty___: if i was to really be straight bold bitches will hate me man
# offensive=  RT @xochaton: you're a little bitch, and I'm straight up rude.
# offensive=  RT @xochinadoll: You hoes are lost.
# offensive=  RT @xofantasybby: A mexican bitch better win the crown! #NuestraBellezaLatina
# offensive=  RT @xojeaninee: &#128553; dawg! &#8220;@Tressilicious: Pet peeve is finding out a cute guy has hoes. I automatically lose interest. I don't compete.&#8221;
# offensive=  RT @xoxo_Geee: Chest tattoos on females are trash .
# offensive=  RT @xoxo_Nieceyy: Lol Imma start handing out guides &amp; manuals cause you bitches wanna be me so bad &#128514;&#128553;&#9995;&#128129;
# offensive=  RT @xoxo_shelby_22: &#8220;@zzachbarness: I'll fuck a bitch real quick&#8221;
# offensive=  RT @xoxokellylynn_: some of y'all hoes can spend $300 on bundles, have a mk purse with a matching wallet, have your nails done but don't ev&#8230;
# offensive=  RT @xsamanthaelaine: 1 good girl is worth 1,000 bitches &amp; people still fail to realize that
# offensive=  RT @xtruthseekerx_: @NotoriousBeep blaxican
# offensive=  RT @xx_lowkeychayy: I let these bitches talk. that's just free promotion &#128079;.
# offensive=  RT @y3llab3lla88: The streets ain't going no where. These hoes for everybody. When you got someone real you hold on to them.
# offensive=  RT @yNeverEleven: @VernNotice "you don't want to play cs:go you're a bitch!" "no I won't play fucking league of legends that game is shit I&#8230;
# offensive=  RT @yaboybillnye: its funny when sluts say "u just mad cause I'm 100% real" its like no bitch #swerve cuz u actually about 65% water gtfo
# offensive=  RT @yaboybillnye: u a 10? on the pH scale maybe cause you basic hoe
# offensive=  RT @yagurlbubblez87: Ugly bitch prolly so cockeyed she lookin at the dick and balls up close at the same time while suckin at the same time
# offensive=  RT @yankee7kid: Who's to blame for the Yankees underperformance this year? The Umps? Management? The Ebola Outbreak?...How 'bout the player&#8230;
# offensive=  RT @yasminmarie23: When you realize you got no hoes http://t.co/s5YVAv8G7l
# offensive=  RT @yayabad1_SODMG: "@_100d: Smoke wit a bitch in nap and let her play music I bet 100 she turn on boosie or some slow shit &#128530;" real shit
# offensive=  RT @yendys45: And @xDSmooth fell in love with pussy he never even got....
# offensive=  RT @yepitstrey: I Be Like
#
# &#128663;_____________&#128659;
# Fuck! Here come the 5'o
#
# __&#128663;______&#128659;__
# Be cool son
#
# ___&#128663;&#128659;_____
# Man fuck
#
# ___&#128659;___&#128663;____
# bitch ass &#8230;
# offensive=  RT @yes_paul: I bitch about unnecessary things lol
# offensive=  RT @ygAddie: Obama a bitch.
# offensive=  RT @yglukeg: Why is Arizona hot as hell and then literally 5 minutes later it's fuckin Hurricane Katrina up in this bitch
# offensive=  RT @yo_fav_rapper: I was HEAD FIRST EVERY TIME FOR YOU. . but now I'm pussy?&#128533;
# offensive=  RT @yoboijackson: Fck all you hoes. Catch a grip!
# offensive=  RT @yofwm: &#8220;@BrianLovesAss_: Damn babe &#128557; sike forever fucking with basic bitches &#128514;&#8221; &#128514;&#128514;
# offensive=  RT @yograndmabitch: Had a crush on a bitch with a man I tried to show her that I could treat her better but I never had no luck
# offensive=  RT @yolythegod: Dick will have bitches selling their own mothers soul.. Inconsistent dick at that. Dick that they know isn't staying.
# offensive=  RT @yooSlim Y'all Virgo bitches gotta chill thinking y'all Beyonc&#232; &#128514;&#128514;&#128514;
# offensive=  RT @youlovelena_: &#8220;@rolltide916: Wtf RT @Ambitious_Rome: &#128553;&#128552;&#128552; &#8220;@__sharae: he peed on this bitch https://t.co/wEJg4IkGIm&#8221;"&#8221; I'll cut his shit
# offensive=  RT @young_thrill3r: These hoes ain't loyal
# offensive=  RT @youngscrap: I sent that bitch a smiley face, bitches love smiley faces &#128515;
# offensive=  RT @youngtravo: If u ain't never had a pregnancy scare your pussy trash ladies #professortrav
# offensive=  RT @younngmel: Fuck half the bitches at Mount Rainier &#58386;&#58386; i only fucks wit a few
# offensive=  RT @yous_a_cutie98: If you know he has a girlfriend don't be that little bitch, respect it and move on.
# offensive=  RT @yummy_pearl4: "You put my number on blocklist? How can I stop this??? Convert them mfs. I'll make all them hoes topless." &#128548;&#128298;
# offensive=  RT @yung_gleesh: If rather fukk a bitch dat fukks eryday den fukk dat bitch who try to hol n be a cold whore n da sheets i cnt een look at &#8230;
# offensive=  RT @yung_sexxistud: Hoes tweets be like put that dick in my throat I won't choke then when you ask them about it they say its a song hoe wh&#8230;
# offensive=  RT @yungbabydad: @RandallSomia because they're all fucking two years old acting like I won't mind being tagged bitch I will violate you
# offensive=  RT @yungkatana: free wop
# offensive=  RT @yunglex3_: Don't want a good girl, hoes is his choice
# offensive=  RT @yunglust: @WeakndMLG @hannahtherapper she a hoe year-round, yeezy taught me
# offensive=  RT @yungtfti: If a bitch says "eeeeeee" she a hoe
# offensive=  RT @yungturd: miley cyrus, macklemore &amp; adam levine all got together n were like "lets gets the most retarded fucking hair cuts ever"
# offensive=  RT @yungxprnce: Approach yo bitch like: http://t.co/UHMIME9psw
# offensive=  RT @yunheaux: ppl from the uk go dumb hard when they curse they be like "YOU SHITTING CUNT" I be like dam cunts can't shit
# offensive=  RT @yurista4life: @weston_diamond @PaulMoon8 fuck you dude! talk shit to my friend I will beat your ass bitch
# offensive=  RT @ywr_speedy: nah these bitches up harbor city ;
# offensive=  RT @z0mbiedance: Gabby's a bitch &amp; made Jackie make the tea packet first.
# offensive=  RT @z0mbiedance: Gabby's a bitch &amp; turned on my xbox with her nasty foot..
# offensive=  RT @z0mbiedance: who let gabby get drunk off of her ass? give that bitch bread...bitches love bread.
# offensive=  RT @zFearless: @Fadeaway_4s fuck a bitch and think of me
# offensive=  RT @zLuketheDuke: @TonyJRodriguez just a bunch of rednecks hammered for three straight days
# offensive=  RT @zachbooty: Building a dresser really makes me crave an ice cold glass of pussy am I right dudes
# offensive=  RT @zachpiecowiak: @Eddie_Sativa87 you're a fucking queer
# offensive=  RT @zachthorpe78: "the trash generation"
# offensive=  RT @zachthorpe78: where are all the thinkpieces on why kids call themselves "trash" and "garbage" these days
# offensive=  RT @zakkmcdaniel: You need to at least not be a bitch 12/7 to date me
# offensive=  RT @zee__emm__gee: I immediately become the biggest bitch when I'm sick. Like I just need to be taken care of lmao
# offensive=  RT @zeemonstaa: There no such thing as too much pussy .
# offensive=  RT @zekNcashe: all i ever asked for was patience, patience &amp; pussy but mostly patience..
# offensive=  RT @zekNcashe: you can't question snoop dogg he a OG he told us not to love these hoes.
# offensive=  RT @zerohedge: Full retard: NAR blaming slow April sales on winter weather.
# offensive=  RT @zippy1981: @voretaq7 from a TDD POV linux is just a mock for the kernel of the GNU/HURD system.
# offensive=  RT @zoejoiner: if you're gonna trash talk my piercings don't say it in front of my best friends &#128514;&#128514;&#128514;&#128514;
# offensive=  RT @zrastall17: Eloquently stated. &#8220;@h0rheyd: god i hate tom coughlin ol ass fuckboy ass geriatric ass pussy ass bitch&#8221;
# offensive=  RT and pass that bitch http://t.co/YoLSpKhiC0
# offensive=  RT if one of your followers sell pussy but hop on Twitter like they got all the morals and class
# offensive=  RT if you fucked a bitch that fucked EVERY nigga in your state
# offensive=  RT to spam this bitch ass nigga RT @HELLonDAscale: Migos http://t.co/5KzQXf7zg9
# offensive=  RT what got me into baseball! :Well only a couple more days till all these legends will be retired #CORE4 #Yankees http://t.co/bL2V1v2n9T&#8221;
# offensive=  RT!
# COMMENCE CARPET BOMBING! All #Iraq soldiers in this video http://t.co/7oLD2eDB1R executed by Jihadis from #Tunis http://t.co/02E1cEOE3z&#8221;
# offensive=  RT!!"@Coolie_GBE300: You pussy whipped for only following @KimKardashian tho.... @kanyewest"
# offensive=  RT"@KILLQuana: I wonder How much pussy justin bieber gets....."
# offensive=  RT'in your own shit now pussy what a joke you'd end up just like all the rest no show chicken shit mother fucker
# offensive=  RT, If You Agree!
# #NorthKorea says #barackobama looks like;
# "A monkey, who belongs in an African zoo"
# ROFL! http://t.co/tooV1uty6h
# offensive=  RT: Thank you, Captain. It'll never be the same. @Yankees #Jeter#2 http://t.co/EIe8D8C5cj&#8221;
# offensive=  Raaaayciss bitch &#8220;@Sky_Max: Michelle Obama: African-Americans Should Vote for Democrats http://t.co/SL6TW6P39f via @Newsmax_Media&#8221;
# offensive=  Rack city bitch !
# offensive=  Raised Round real niccas no decoy
# offensive=  Rally's sound good af. But ion have no hoes so we can't take that ride &#128530;
# offensive=  Rambo bout to flex on these hoes
# offensive=  Rams too "@GnarlsDarkley: Lakers as a whole is trash RT @80sbaby4life: Jordan Hill is trash. Play Davis and Randle more"
# offensive=  Ran here from my house too... I'm kinda retarded. Lol
# offensive=  Rand went full retard some time ago &#8220;@RichardBSpencer: @SenRandPaul isn't "playing the game"... he's just retarded.
#  http://t.co/ZpKimh9fTG&#8221;
# offensive=  Rap bitches prolly scared of Remy ma lol
# offensive=  Rape a ho Ben! Lol
# offensive=  Ratchet lol ass lol bitch
# offensive=  Raunchy ass hoe.
# offensive=  Raunchy ass to pussy action with Sakurako offering up her holes for&#160;use http://t.co/9elp4XyE9D
# offensive=  Ravioli stuffed wit lobster nd a nice stuffed clam #eating betterthanamobster http://t.co/PzdoESaR
# offensive=  Ray Rice bitch!!!!!!!!!!!!!
# offensive=  Ray Rice is a bitch &amp; his wife is stupid for staying by his side.
# offensive=  Ray rice had that bitch of the xans and the lean all in one punch
# offensive=  Re: Alexander Skarsgard, my roommate has declared: "He's a sexy albino lizard. i dont know how that's sexy, but it kinda is."
# offensive=  Reaaallly wish I had more milk for Oreos. Lol
# offensive=  Reading the ut sexual assault case takes me back 2 college.I'll never forget D Walk would say dont run trains on them hoes.Straight Trouble
# offensive=  Ready to bounce out dis bitch
# offensive=  Ready to go get my fried Oreos
# offensive=  Real Niggas and Bad bitches have 2 things in common. You're both ignorant as fuck &amp; neither of you know that you're Kings and Queens.
# offensive=  Real basketball players get disappointed when they throw something in the trash can and miss
# offensive=  Real bitches who really hungry won't be out here arguing with bitches on twitter straight flexin
# offensive=  Real love hard to find when these bitches try to fake it with me
# offensive=  Real niccas relate fuk niccas perpetrate
# offensive=  Real nigga need a real bitch. Just somebody I can chill with.&#128107;&#10084;
# offensive=  Real niggas let real bitches come &#128070;
# offensive=  Real niggas let real bitches cum first &#128540;
# offensive=  Real niggas speaking bitch u better listen....
# offensive=  Real niggas treat me with respect and you're a pussy, nigga.
# offensive=  Real nigs uck with me and I don't give a uck who don't
# offensive=  Real shit. Now if the bitch want some grapes or something, THATS different.
# offensive=  Real shit: I love eating pussy.
# offensive=  Real talk I really ain't fully trusted a bitch since Instagram and twitter became popular
# offensive=  Real talk not being byes or nothin! The whole NFC south glad bag trash this year none of the teams have a chance making it to the playoffs!
# offensive=  Really Barnicle? OJ or Anthony Weiner? MJ is a clown show for #teabaggers and the rich. Come on #msnbc do you want good ratings? #morningjoe
# offensive=  Really ain't nuttin to cut that bitch off
# offensive=  Really bitch?
# offensive=  Really bitch? No.
# offensive=  Really craving my arroz con pollo y habichuelas right now
# offensive=  Really tempted to let out the redneck side of my drink a lot of beer and sing some country karaoke..
# offensive=  Really wanna go biking downtown. The current lack of sunglasses... Not cool. Not happy. Prepare the bitch face.
# offensive=  Really. 3 hours to find paper work is retarded. Tarrant County Courts suck.
# #wasteoftime
# offensive=  Reaper drones pinpoint Jihadi John http://t.co/IBScZeLxXe via @MailOnline
# offensive=  Reathie phone jumping out the gym finna cut this bitch off
# offensive=  Reathie scared thenna bitch
# offensive=  Receipts? RT @LoyalLamb85: I still remember that time Lawrence left me a vile voice mail. He was angry. Called me a ho and everything. Lol
# offensive=  Red Sox fans bitch the loudest about right field. Their hitters exempt from hitting them out too? #Yankees #YankeeStadium
# offensive=  Red bitch with me dark skin friend callin talkin bout come and get me
# offensive=  Ref finally calls it when it's an arm ball but those hoes didn't count the hand ball in the Mexico game. K #yesiamstillsalty
# offensive=  Regular joes rockin tha boat that's us redneck yacht clubbb&#9728;&#127926;
# offensive=  Reina Yoshii in cock blowing threesome with her hairy pussy teasing&#160;cock http://t.co/dT4vmEPtv4
# offensive=  Remember that fear is there to guide you, not cripple you.
# offensive=  Remember when I said Uchiha&#8217;s are faggots? This week Sasuke reaffirms that with flying colors.
# offensive=  Remember when I told yall bout my coworker not lookin out a couple weeks back?.. Karma's a hoe, got his ass.
# offensive=  Remember when I would spank everyone in meme wars? Because I do #faggots
# offensive=  Remember when black girls out numbers in front of shit. "I'm 9 hungry" "You 7 stupid hoe"
# offensive=  Reminiscin on my swinger days, when I drove a Caddy and my bitch sported a finger wave
# offensive=  Repeat after me: Where my bitches?
# offensive=  Republicans aren't the only racist in America. We have racist Democrats too. But don't play the token negro card... http://t.co/FT5c4yhraG
# offensive=  Rescue elephant calf &#8216;Nunai&#8217; looking fuzzy at the International Fund for Animal Welfare Rehabilitati http://t.co/PAetLXGuoa
# offensive=  Retweet to spam this faggot RT @ChickenColeman: Dick going &#128070;
# offensive=  Rev. Charlie Rangel: What Unions Stand For Are &#8220;Spiritual Damn Things&#8221;&#8230; LIKE INFLATABLE RATS.
#
#  http://t.co/2nmrLDvIgB
# offensive=  Review: The Yanks are Coming! A Military History of the United States in World War I http://t.co/Hv4k1yZACH via @BreitbartNews
# offensive=  Rewrite, tinker with it's official language regarding same-sex relationships, divorce, remarriage, etc. But nothing is set in stone at all.
# offensive=  Rick is not a bitch.
# #TheWalkingDead
# offensive=  Ricky is such a bitch when it comes to girls&#128530;
# offensive=  Riding in that ooo bitch it's nasty
# offensive=  Riding my quad with this bitch &#128540; http://t.co/EpPeMQfXxO
# offensive=  Riding wit my old dude .. Dis nicca bangin #FreshPrince #Summertime &#128514;&#128514;&#128563;&#128533;&#128559;&#9995;
# offensive=  Rihanna just slaying any bitch &#128525;&#128525;
# ...
# Right by the pussy with nothin' on my mind
# offensive=  this fat bitch was preaching like "we have too many fat and lazy people!!" haVE YOU SEEN A MIRROR WTF
# offensive=  this guy @ToksVisions is in here singing negro spirituals n shit
# offensive=  this guy is the biggest faggot omfg
# offensive=  this hair screams bitch
# offensive=  this ho on Lifetime cray
# offensive=  this is why i love birds. http://t.co/Gk2wiNhBkw
# offensive=  this lady is probably like "what the fuck does this bitch listen to"
# offensive=  this movie is actually good cuz its so retarded
# offensive=  this nigga @WaynesWorld171 fucking a bitch at svsu while me rj and b been waiting in the car for 20 minutes now
# offensive=  this one bitch dont feel the same no more an henny dont really kill the pain no moree
# offensive=  this party goin be off the chain/bad bitches only http://t.co/Qx7BZLFh
# offensive=  this shit so trash lol
# offensive=  this show trash RT @IbSkeeAlii: #LongLive RT @ShinyLipz: Queen Latifah show.... &#128564;&#128564;&#128564;&#128564;
# offensive=  this the one&#128076;RT @SumthinNueee hoes dont be wantin ya nigga, they want ya happiness, thinkin he gone do 4 them what he does for u&#128514; silly hoes
# offensive=  this ugly bitch need to get a new name tho you don't look like me you don't have as much followers as me #killyouself zodiac killer bitch
# offensive=  this why i need bitches
# offensive=  those random kids who sit at the plaza all day with their shitty cars #faggots
# offensive=  thot hoe
# offensive=  thugga let ur bitch suck'em up in rentals!!!
# offensive=  thus bitch looks just like Lindsay Lohan she gets down just like Lindsay Lohan #DetroitGirls &#128525;&#128103;&#128103;&#10084;&#10084;&#10084;
# offensive=  timbs straight trash though
# offensive=  time to start an Army of hoes
# offensive=  to me niggas cheat on they bad bitches bc they think they can get more bad bitches, that one girl will give em a big ass ego
# offensive=  today i start breaking in a new pair of docs have mercy on my soles
# offensive=  today my friend taught me so hood slang &#128514; she said fuck nigga, nigga bitch, fuck boy, nigga bruh &#128557;&#128553;
# offensive=  tom ford probably fucking all these hoes
# offensive=  too bad ur a pussy
# offensive=  too many bitches, not enough adults.
# offensive=  too many grown man out here worryin' about the friendzone....yall got priorities fucked my nig
# offensive=  top layer trash.
# offensive=  top notch hoes get the most not the lesser
# offensive=  trash RT @AyeoFool: Easily the "Real Gs move n silence like lasagna" line RT @SHAWNHINDRIIX: RT WIT A WAYNE LINE THAT WENT OVER NIGGAS HEADS
# offensive=  trash RT @VibeMagazine: Can the Notorious B.I.G.&#8217;s son CJ Wallace rap? Watch &amp; vote here: http://t.co/3kzJj7nqpP http://t.co/wOwnc0A70P
# offensive=  trash af
# offensive=  trash both ways lol RT @AgdaCoroner: Bitch Killed Herself....Look Like Bill Maher With Makeup on http://t.co/IWLAG2J5Sl
# offensive=  trash http://t.co/oeDKEHyyXJ
# offensive=  trash night tonight. I can already hear the sound of America's thriving economic sector out on the street, four wheels, one of them wobbles.
# offensive=  trash show
# offensive=  tricking off ya paper ain't wat u do... gotta learn the game... make dat hoe buy u!!!!
# offensive=  triple fudge brownie chunk ice cream #LifeChanging
# offensive=  triple nipple ass hoes!!
# offensive=  trust me, just set the alpha to 0. it's just as good (maybe better) than setting the visibility to false. now: fly on silver bird!
# offensive=  tryna get grey to call off work but he's being a bitch lol
# offensive=  turns out his ex-boss called him a pussy. he lasted a week and a day. You can call me anything, just don't touch. but I am not 25 anymore.
# offensive=  type a bitch make u take her on 10 dates, then she give u da pussya and the shit weak. damn.
# offensive=  u a hoe
# offensive=  u a stupid hoe
# offensive=  u can tell yo bitch we some yung rich homies
# offensive=  u ho@RealWizKhalifa u hot i really like the way u keep te flow natural
# offensive=  u know I came to stunt
# so drop that pussy bitch
# offensive=  u know u watch too much gay porn when u refer to boy butts as "man ass" or "boy pussy" bc me in my head 24/7
# offensive=  u lucky he holdin me back bitch http://t.co/HanER6B9Ts
# offensive=  u sent nudes when ina relationship or nah? "@JazmineJanay_: Her pussy bleeding or nah? "@GraePharoah: -_- http://t.co/W9ZPJfk93r"
# offensive=  u should be here wit me bitch
# offensive=  u stupid bitch
# offensive=  u that nigga RT @Charmin_Harmon I have no idea how random jiggas be knowing my name at work smh.
# offensive=  u want a cookie tomorrow bitch @_lostb0y
# offensive=  u-bitch-u
# offensive=  ugh&#8230; the bitch name was Leather&#8230;
# offensive=  ugly hoe
# offensive=  under my windoowww &#8220;@brettcanfly: Bleaching your teeth, smiling flash, talking trash, under your breath&#8221;
# offensive=  ur trash! http://t.co/6KN7PzTgl8
# offensive=  versace bird feeder
# offensive=  waaaaay too many niggas comfortable wit dressing up like ugly bitches for IG likes an re-posts....
# offensive=  wack bitches make me curve them
# offensive=  walking dead gonna be so trash this season
# offensive=  walking down the st and this girl with a guy past me and the girl says I'm bout to turn dyke for her ctfuu classic
# offensive=  wallah I fucking hate this fuckin mexican bitch so much.
# offensive=  wanna make a boss happy? &#128527;
# bitch talk nasty. &#128540;
# offensive=  want to catch my attention niggah throw up a dolla sign
# offensive=  was just informed that "crunk ain't dead ho!"&#8230; lol okay sure
# offensive=  watch out for these foul hoes and flagrant niggas!
# offensive=  we all went through so much shit together . I miss them bitches
# offensive=  we dem birds.
# offensive=  we don't pay hoes... we don't save hoes
# offensive=  we in here turn up turn up wheres the bitches
# offensive=  we live in a world where drake can steal your hoes and make fun of you, shit crazy
# offensive=  we need to pile some hoes in the back of Ross' car
# offensive=  we'ont get head from hoes wit overbites..
# offensive=  wearing pajamas tonight 4 da gook
# UDigg
#
# Grey day
# offensive=  weeknd makes songs for the hoes
# offensive=  well ain't that a bitch
# offensive=  well i want to be Victoria's Secret dyke angel&#128124;&#128149;
# offensive=  were gunna shake our honkey tonk badonkadonks (': @SAMMI_boyden
# offensive=  what a broke niggah gone tell her.
# offensive=  what a clam shame
# offensive=  what a hoe
# offensive=  what a little bitch lol
# offensive=  what a retard lol
# offensive=  what he was clearly stating to the masses is....pussy is to be shared...so girl send out dat pussy to my shark
# offensive=  what to do when your ear hurts like a bitch?
# offensive=  what's wrong with bitches fuck nigga
# offensive=  when Em said "I'm on my straight grizzly, so why would I buy you a gay ass teddy bear bitch youre already bi-polar." http://t.co/FQquXTxHBo
# offensive=  when a bitch say you cant dance http://t.co/GKZj7QNDIF
# offensive=  when ah rich nigga want ur bitch it's nothing u can do... but hope she think about u on dem shopping sprees...
# offensive=  when baylor wins im talking so much trash
# offensive=  when bitches be tryna wash their shit on the low lol funny af
# offensive=  when bitches change and start acting like the nigga they with &lt;&lt;&lt;&lt;&lt;&lt;
# offensive=  when bitches u hate won't stop staring at u in the halls http://t.co/OjNXhoIGdw
# offensive=  when im there with a ghetto ass accent being shy as hell like
# offensive=  when nino said "cancel that bitch ill buy a new one" &gt;&gt;&gt;&gt;&gt;&gt;&gt;&gt;&gt;&gt;&gt;
# offensive=  when the dude shoots his jiz in the bitches eye in silence of the lambs
# offensive=  when ya name gain weight ya ex bitches cant let go
# offensive=  when ya name gain weight ya ex hoes can't let go
# offensive=  when yo song come on and you hit the blunt hard af cause that hoe go dat hard
# offensive=  when you first walked in the door at that party you saw a big booty hoe &#8212; Name ? http://t.co/JERsrSwhUe
# offensive=  when you're stupid, you don't know it. life is so easy. have you ever seen a depressed retard? i envy that.
# offensive=  where da ratchet hoes at?
# offensive=  where my scene hoes at?
# offensive=  where r the fun twins at @TheJsimps I'm trying to lick cheeto dust and coleslaw off your nips
# offensive=  whheeet bitch you LYING
# offensive=  which one of these names is more offensive kike, wop, kraut, wetback jigaboo, towelhead, gook, or redskin.
# offensive=  which twitter bitch isn't selling chokers&#10068;&#10068;
# offensive=  who's downie like a brownie 4 brunch? Need mimosas
# offensive=  who's pussy better then a crazy bitch?
# offensive=  why are people acting like they didn't know hoe allen was going to the cavs 6 months ago?
# offensive=  why are these freshman so ghetto lmao
# offensive=  why bitches gotta be bitches
# offensive=  why cant girls just admit that they want the dick as much as us guys want the pussy? human nature duhh
# offensive=  why did the fins sign finnegan? hes a certified bitch
# offensive=  why do hoes think its a good idea to air out their dirty laundry at a public place? bitch im tryna enjoy my burrito
# offensive=  why do little scrawny white boys play ghetto rap music while they walk around.
# offensive=  why even get pregnant by someone that isn't an never will be fit to be a dad, smh stupid stupid hoes
# offensive=  why is this thirsty white basic ass bitch still talking to me gtfo
# offensive=  why lie tho&#8230;&#8230; we gon' find you bitches
# offensive=  why niggas put heart eyes under everybody pictures? &#128553; then it be them poo la la hoes.
# offensive=  why should there be an age limit on movies?
# it ain't their fault if a 13yr old is traumatized from an R rates film
# bunch of pussies
# offensive=  why tf is this bitch in my class wearing all brewers shit it's football season,,,,
# offensive=  why the fuck did twitter move the new tweet box to above the feed lol it looks fucking retarded
# offensive=  why they playing trash on ESPN right now.
# offensive=  why you act like a little booshie bitch now, that's why you don't have friends hoe
# offensive=  why you think ol niggas wit no money dont even care about swag, rockin sandals wit velcor straps, they aint checkin for bitches
# offensive=  whys this bitch wearing a striped tshirt and nike shocks
# offensive=  will u love dat nigga even if he lose it all... or will u dip like the groupie hoes searching for another &#11088;&#65039;
# offensive=  will u sell dat pussy for me?
# offensive=  wish I had a brownie or a dab to knock me out rn
# offensive=  wishing I could high five whoever named a species of birds "great tits"
# offensive=  with Louisville (5) losing last night, a win to #iubb (7) tonight should have them back in the top 5! #ncaa #basketball #iu #hoosiers
# offensive=  women hate hoes becuz they fuckin up the economy
# offensive=  wonder if they gon have em for the low on nigger friday....
# offensive=  wondertrade is the best pokemon feature ever. i just got a level 27 japanese wobbuffet for a level 4 beginning area trash pokemon
# offensive=  worst thing a bitch can do &#8220;@loyalshawn: Bitches main reason for being in another nigga face is to get they nigga jealous . &#128078; Wack .&#8221;
# offensive=  wouldn't be such a bitch if people didn't piss me off 24/7
# offensive=  wow im a bitch????? nice to fucking know.
# offensive=  wow im gonna smoke myself retarded when i get home
# offensive=  wow! RT @Tendilkar: RT @LyricalSunset: RT @LilMissCuntCake: Some bitches just deserve to get punched. In the vagina.
# offensive=  wow.... a bird just shitted on me
# offensive=  wth is that playing missy? ........ i mean seriously? RT @mr_republicann: This movie gone be trash http://t.co/8BIppVUvzr
# offensive=  wut spook me even more is its gon be dark when nigga drive outta hea..... im sick already
# offensive=  x_x RT @LaDarinAintShit: Fat bitches with normal sized legs be looking like car keys.
# offensive=  y give a bitch an inch when she rather have 9
# offensive=  y'all I'm so mad I wasted them calories on that honey bun.. that ho was dry as hell &#128553;
# offensive=  y'all hoes avoid schemes
# offensive=  y'all moms was hoes with no morals so i ain't surprised
# offensive=  y'all remember that tall ass dyke named Jay??? Lmfaooo
# offensive=  ya bitch aint bad nigga, you aint got no taste
# offensive=  ya girl pussy is trash as fuck.
# offensive=  ya'll niggers have a good thanksgiving
# offensive=  yal some faggots yup nigga you n you fuckin fruit cups.
# offensive=  yall crazy hoes need jesus lol
# offensive=  yall pussies i swur
# offensive=  yay I like when jacob has colored layouts
# offensive=  yaya ho.. cute avi tho RT @ViVaLa_Ari I had no idea she was sleep &#128553;
# offensive=  yea so about @N_tel 's new friend.. all my friends kno they're only allowed one cute darkie friend n that's me! lol
# offensive=  yeah I'm a bitch, but guess what? you're still a slut.
# offensive=  yeah I'm small den a hoe http://t.co/VV3qdTo7MG
# offensive=  yeah i got soul i was brought up by colored women.
# offensive=  yeah these valley faggots can go fuck themselves
# offensive=  yes good shapely eurotrash manbooty
# offensive=  yet this nigga still checkin up on his old hoes.....
# offensive=  yo bitch bitch gone let me fuck tonight
# thursty Thursday at the WesGod cave
# offensive=  yo bitch look like a boogawolf
# offensive=  yo bitch want that vitamin D she lookin desperate
# offensive=  yo bitch whippin in the early morning
# offensive=  yo hoe will get slayed . &#128298;&#128298;
# offensive=  yo hoe will get slayed! &#128298;
# offensive=  you a hoe nigga forreal
# offensive=  you a pussy ass nigga and I know it nigga.
# offensive=  you ain't a real nigga without goal a to chase and a yellow bone bitch w/ some toes to paint
# offensive=  you ain't gotta be a dyke to like hoes
# offensive=  you are a hoe, hoe, &amp; a hoe.
# offensive=  you bitches love yall some corny nigga
# offensive=  you can masturbate anytime bitch lol &#8220;@greyyygoose: I just want some damn alone time. Fucccckkkkkk! Lol&#8221;
# offensive=  you can never get a group of hoes together witout em resorting to being hoes....
# offensive=  you can tell when dick recently been in a pussy, taste nasty af ewww bitches better never play that shit
# offensive=  you can't cuff a hoe lmao
# offensive=  you drove me redneck crazy
# offensive=  you fake niggah lolol
# offensive=  you got niggas, and i got bitches.
# offensive=  you gotta be a new breed of retarded if you do that. http://t.co/PeinRwsZzq
# offensive=  you gotta understand that these bitches are childish
# offensive=  you hoe spice
# offensive=  you just want some attention hoe
# offensive=  you know what they say, the early bird gets the worm. *puts gummy worms in your morning coffee*
# offensive=  you know what your doing when you favorite a tweet, tryna cheat ass bitch haha
# offensive=  you lil dumb ass bitch, i ain't fuckin wit chu!.. i got a million, trillion things i'd rather fuckin' do.. than to be fuckin witchu.
# offensive=  you look like AC Green...bitch don't call here anymore...
# offensive=  you look like your 12 stop talking about fucking bitches &#9757;
# offensive=  you might as well gone pussy pop on a stage
# offensive=  you niggers cheat on ya gf's? smh....
# offensive=  you really care bout dis bitch. my dick all in yo feelings
# offensive=  you worried bout other bitches, you need me for?
# offensive=  you're all niggers
# offensive=  you're such a retard i hope you get type 2 diabetes and die from a sugar rush you fucking faggot @Dare_ILK
# offensive=  you's a muthaf***in lie &#8220;@LifeAsKing: @20_Pearls @corey_emanuel right! His TL is trash &#8230;. Now, mine? Bible scriptures and hymns&#8221;
# offensive=  you've gone and broke the wrong heart baby, and drove me redneck crazy
# offensive=  young buck wanna eat!!.. dat nigguh like I aint fuckin dis up again
# offensive=  youu got wild bitches tellin you lies
# offensive=  ~~Ruffled | Ntac Eileen Dahlia - Beautiful color combination of pink, orange, yellow &amp; white. A Coll http://t.co/H0dYEBvnZB

# %%
# finding total  number of offensive tweets in data set

print(f"Total offensive tweets in dataset = {row_counter}")

#print(high_tweet)
max_words = max(zip(dict1.values(), dict1.keys()))[1]
# Out:
# Total offensive tweets in dataset = 24784

# %%
# Printing most offfensive tweet
# inorder to print most offensive tweet I finding that tweet number , iam interating through again file and incrementing counter
# when the counter im printing that tweet and breaking from the loop 

import csv

with open('/content/drive/MyDrive/Colab Notebooks/labeled_data.csv') as csvfile:
  reader = csv.DictReader(csvfile)
  high_count = 0
  for row in reader:
    high_count = high_count + 1
    if high_count == max_words:
      print(f'most offensive =  {row["tweet"]}')
      break


print(f"Total offensive tweets in dataset = {row_counter}")

#print(high_tweet)
max_words = max(zip(dict1.values(), dict1.keys()))[1]
# Out:
# most offensive =  @OfficialSkai dont tell me what to do. fuck balls kike nigger cunt tits cocksucker chink spic piss bitch bastard pussy faggot.
# Total offensive tweets in dataset = 24784

# %%
# Out:
# {1: 3, 2: 3, 3: 9, 4: 2, 5: 7, 6: 13, 7: 5, 8: 6, 9: 4, 10: 6, 11: 4, 12: 4, 13: 4, 14: 5, 15: 4, 16: 7, 17: 4, 18: 5, 19: 5, 20: 5, 21: 4, 22: 4, 23: 3, 24: 10, 25: 5, 26: 3, 27: 2, 28: 3, 29: 9, 30: 5, 31: 6, 32: 5, 33: 6, 34: 3, 35: 6, 36: 4, 37: 4, 38: 7, 39: 4, 40: 3, 41: 4, 42: 3, 43: 4, 44: 5, 45: 3, 46: 5, 47: 3, 48: 9, 49: 5, 50: 6, 51: 8, 52: 10, 53: 5, 54: 5, 55: 4, 56: 8, 57: 5, 58: 2, 59: 4, 60: 9, 61: 6, 62: 8, 63: 4, 64: 2, 65: 5, 66: 4, 67: 3, 68: 1, 69: 8, 70: 10, 71: 1, 72: 6, 73: 4, 74: 6, 75: 7, 76: 1, 77: 2, 78: 8, 79: 5, 80: 8, 81: 6, 82: 9, 83: 4, 84: 4, 85: 5, 86: 4, 87: 4, 88: 5, 89: 5, 90: 6, 91: 3, 92: 5, 93: 5, 94: 6, 95: 4, 96: 6, 97: 8, 98: 6, 99: 4, 100: 3, 101: 8, 102: 6, 103: 4, 104: 4, 105: 2, 106: 3, 107: 3, 108: 4, 109: 5, 110: 6, 111: 10, 112: 9, 113: 4, 114: 4, 115: 5, 116: 1, 117: 9, 118: 7, 119: 3, 120: 6, 121: 3, 122: 4, 123: 1, 124: 4, 125: 4, 126: 6, 127: 4, 128: 5, 129: 5, 130: 4, 131: 5, 132: 7, 133: 9, 134: 4, 135: 3, 136: 4, 137: 4, 138: 6, 139: 9, 140: 16, 141: 1, 142: 2, 143: 2, 144: 5, 145: 12, 146: 4, 147: 7, 148: 3, 149: 4, 150: 4, 151: 4, 152: 3, 153: 7, 154: 10, 155: 5, 156: 6, 157: 4, 158: 8, 159: 4, 160: 2, 161: 2, 162: 8, 163: 3, 164: 5, 165: 3, 166: 3, 167: 6, 168: 8, 169: 5, 170: 3, 171: 6, 172: 5, 173: 3, 174: 7, 175: 3, 176: 5, 177: 5, 178: 4, 179: 11, 180: 5, 181: 1, 182: 3, 183: 3, 184: 4, 185: 6, 186: 5, 187: 4, 188: 1, 189: 4, 190: 4, 191: 2, 192: 6, 193: 7, 194: 7, 195: 5, 196: 8, 197: 3, 198: 5, 199: 5, 200: 5, 201: 7, 202: 2, 203: 4, 204: 5, 205: 2, 206: 3, 207: 2, 208: 6, 209: 3, 210: 9, 211: 4, 212: 3, 213: 4, 214: 3, 215: 6, 216: 4, 217: 4, 218: 5, 219: 4, 220: 4, 221: 1, 222: 3, 223: 9, 224: 3, 225: 3, 226: 5, 227: 8, 228: 11, 229: 5, 230: 4, 231: 4, 232: 7, 233: 7, 234: 5, 235: 6, 236: 10, 237: 3, 238: 2, 239: 6, 240: 8, 241: 1, 242: 7, 243: 5, 244: 3, 245: 4, 246: 6, 247: 4, 248: 3, 249: 4, 250: 3, 251: 4, 252: 13, 253: 3, 254: 6, 255: 4, 256: 3, 257: 5, 258: 7, 259: 3, 260: 1, 261: 5, 262: 5, 263: 8, 264: 4, 265: 4, 266: 8, 267: 4, 268: 4, 269: 2, 270: 3, 271: 7, 272: 5, 273: 7, 274: 8, 275: 3, 276: 4, 277: 4, 278: 5, 279: 5, 280: 7, 281: 3, 282: 2, 283: 4, 284: 2, 285: 3, 286: 7, 287: 7, 288: 9, 289: 2, 290: 6, 291: 5, 292: 5, 293: 12, 294: 7, 295: 9, 296: 6, 297: 3, 298: 5, 299: 2, 300: 6, 301: 10, 302: 2, 303: 10, 304: 7, 305: 6, 306: 5, 307: 6, 308: 4, 309: 1, 310: 8, 311: 5, 312: 11, 313: 3, 314: 1, 315: 5, 316: 7, 317: 8, 318: 2, 319: 4, 320: 4, 321: 5, 322: 3, 323: 5, 324: 3, 325: 7, 326: 5, 327: 5, 328: 4, 329: 10, 330: 2, 331: 12, 332: 1, 333: 3, 334: 3, 335: 4, 336: 10, 337: 2, 338: 3, 339: 7, 340: 14, 341: 9, 342: 3, 343: 5, 344: 1, 345: 6, 346: 5, 347: 3, 348: 5, 349: 3, 350: 4, 351: 7, 352: 3, 353: 4, 354: 4, 355: 6, 356: 3, 357: 2, 358: 5, 359: 15, 360: 12, 361: 4, 362: 4, 363: 6, 364: 4, 365: 4, 366: 4, 367: 7, 368: 5, 369: 5, 370: 7, 371: 2, 372: 9, 373: 3, 374: 6, 375: 8, 376: 5, 377: 10, 378: 5, 379: 5, 380: 3, 381: 3, 382: 9, 383: 3, 384: 2, 385: 1, 386: 8, 387: 2, 388: 5, 389: 5, 390: 12, 391: 3, 392: 3, 393: 8, 394: 7, 395: 7, 396: 4, 397: 7, 398: 3, 399: 7, 400: 6, 401: 4, 402: 7, 403: 6, 404: 4, 405: 5, 406: 4, 407: 4, 408: 3, 409: 9, 410: 11, 411: 9, 412: 5, 413: 4, 414: 2, 415: 2, 416: 3, 417: 9, 418: 5, 419: 4, 420: 4, 421: 5, 422: 5, 423: 4, 424: 4, 425: 2, 426: 10, 427: 2, 428: 5, 429: 2, 430: 6, 431: 5, 432: 7, 433: 2, 434: 4, 435: 3, 436: 8, 437: 5, 438: 13, 439: 3, 440: 5, 441: 6, 442: 6, 443: 1, 444: 4, 445: 3, 446: 13, 447: 5, 448: 8, 449: 7, 450: 2, 451: 5, 452: 8, 453: 3, 454: 4, 455: 3, 456: 5, 457: 7, 458: 9, 459: 3, 460: 7, 461: 3, 462: 4, 463: 5, 464: 3, 465: 4, 466: 12, 467: 2, 468: 4, 469: 6, 470: 5, 471: 4, 472: 4, 473: 3, 474: 2, 475: 12, 476: 5, 477: 5, 478: 9, 479: 4, 480: 5, 481: 4, 482: 10, 483: 4, 484: 9, 485: 4, 486: 4, 487: 3, 488: 5, 489: 4, 490: 6, 491: 8, 492: 4, 493: 4, 494: 3, 495: 1, 496: 9, 497: 3, 498: 7, 499: 5, 500: 2, 501: 5, 502: 7, 503: 12, 504: 4, 505: 5, 506: 3, 507: 4, 508: 11, 509: 3, 51 ...
